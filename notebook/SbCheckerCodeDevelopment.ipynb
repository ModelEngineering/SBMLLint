# %%
import __init__
import sys
import tellurium as te
import tesbml
import print_model
import simple_sbml

# %% [markdown]
# # Reading a document

# %%
def check(value, message):
   """If 'value' is None, prints an error message constructed using
   'message' and then exits with status code 1.  If 'value' is an integer,
   it assumes it is a libSBML return status code.  If the code value is
   LIBSBML_OPERATION_SUCCESS, returns without further action; if it is not,
   prints an error message constructed using 'message' along with text from
   libSBML explaining the meaning of the code, and exits with status code 1.
   """
   if value == None:
     raise SystemExit('LibSBML returned a null value trying to ' + message + '.')
   elif type(value) is int:
     if value == LIBSBML_OPERATION_SUCCESS:
       return
     else:
       err_msg = 'Error encountered trying to ' + message + '.' \
                 + 'LibSBML returned error code ' + str(value) + ': "' \
                 + OperationReturnValue_toString(value).strip() + '"'
       raise SystemExit(err_msg)
   else:
     return

# %%
length = 3
format(length, '010')
# Out:
# '0000000003'

# %%
rr = te.tellurium.RoadRunner("http://www.ebi.ac.uk/biomodels-main/download?mid=BIOMD0000000023")

# %%
stg = rr.getCurrentSBML()
reader = tesbml.SBMLReader()
document = reader.readSBMLFromString(stg)
model = document.getModel()
type(model)
# Out:
# tesbml.libsbml.Model

# %%
model.name
# Out:
# 'Rohwer2001_Sucrose'

# %%
dir(document)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__swig_getmethods__',
#  '__swig_setmethods__',
#  '__weakref__',
#  '_s',
#  'addCVTerm',
#  'addUnknownPackageRequired',
#  'addValidator',
#  'all_elements',
#  'all_elements_from_plugins',
#  'annotation',
#  'annotation_string',
#  'appendAnnotation',
#  'appendNotes',
#  'applicable_validators',
#  'checkCompatibility',
#  'checkConsistency',
#  'checkConsistencyWithStrictUnits',
#  'checkInternalConsistency',
#  'checkL1Compatibility',
#  'checkL2v1Compatibility',
#  'checkL2v2Compatibility',
#  'checkL2v3Compatibility',
#  'checkL2v4Compatibility',
#  'checkL2v5Compatibility',
#  'checkL3v1Compatibility',
#  'checkL3v2Compatibility',
#  'checkMathMLNamespace',
#  'clearValidators',
#  'clone',
#  'column',
#  'connectToChild',
#  'connectToParent',
#  'consistency_checks',
#  'consistency_checks_for_conversion',
#  'containsUndeclaredUnits',
#  'conversion_validators',
#  'convert',
#  'createModel',
#  'cv_terms',
#  'deleteDisabledPlugins',
#  'derived_unit_definition',
#  'disablePackage',
#  'divideAssignmentsToSIdByFunction',
#  'element_name',
#  'enableDefaultNS',
#  'enablePackage',
#  'enablePackageInternal',
#  'expandFunctionDefinitions',
#  'expandInitialAssignments',
#  'getAncestorOfType',
#  'getAnnotation',
#  'getAnnotationString',
#  'getApplicableValidators',
#  'getCVTerm',
#  'getCVTerms',
#  'getColumn',
#  'getConversionValidators',
#  'getDefaultLevel',
#  'getDefaultVersion',
#  'getDerivedUnitDefinition',
#  'getDisabledPlugin',
#  'getElementByMetaId',
#  'getElementBySId',
#  'getElementFromPluginsByMetaId',
#  'getElementFromPluginsBySId',
#  'getElementName',
#  'getError',
#  'getErrorLog',
#  'getErrorWithSeverity',
#  'getId',
#  'getIdAttribute',
#  'getLevel',
#  'getLine',
#  'getListOfAllElements',
#  'getListOfAllElementsFromPlugins',
#  'getLocationURI',
#  'getMetaId',
#  'getModel',
#  'getModelHistory',
#  'getName',
#  'getNamespaces',
#  'getNotes',
#  'getNotesString',
#  'getNumCVTerms',
#  'getNumDisabledPlugins',
#  'getNumErrors',
#  'getNumPlugins',
#  'getNumUnknownPackages',
#  'getNumValidators',
#  'getObjectVersion',
#  'getPackageName',
#  'getPackageRequired',
#  'getPackageVersion',
#  'getParentSBMLObject',
#  'getPkgRequired',
#  'getPlugin',
#  'getPrefix',
#  'getResourceBiologicalQualifier',
#  'getResourceModelQualifier',
#  'getSBMLDocument',
#  'getSBMLNamespaces',
#  'getSBOTerm',
#  'getSBOTermAsURL',
#  'getSBOTermID',
#  'getTypeCode',
#  'getURI',
#  'getUnknownPackagePrefix',
#  'getUnknownPackageURI',
#  'getValidator',
#  'getVersion',
#  'hasNonstandardIdentifierBeginningWith',
#  'hasOptionalAttributes',
#  'hasOptionalElements',
#  'hasRequiredAttributes',
#  'hasRequiredElements',
#  'hasUnknownPackage',
#  'hasValidLevelVersionNamespaceCombination',
#  'id',
#  'id_attribute',
#  'isDisabledIgnoredPackage',
#  'isEnabledDefaultNS',
#  'isIgnoredPackage',
#  'isIgnoredPkg',
#  'isPackageEnabled',
#  'isPackageURIEnabled',
#  'isPkgEnabled',
#  'isPkgURIEnabled',
#  'isSetAnnotation',
#  'isSetId',
#  'isSetIdAttribute',
#  'isSetMetaId',
#  'isSetModel',
#  'isSetModelHistory',
#  'isSetName',
#  'isSetNotes',
#  'isSetPackageRequired',
#  'isSetPkgRequired',
#  'isSetSBOTerm',
#  'isSetUserData',
#  'level',
#  'level_and_version',
#  'line',
#  'matchesRequiredSBMLNamespacesForAddition',
#  'matchesSBMLNamespaces',
#  'meta_id',
#  'model',
#  'multiplyAssignmentsToSIdByFunction',
#  'name',
#  'namespaces',
#  'notes',
#  'notes_string',
#  'num_cv_terms',
#  'num_disabled_plugins',
#  'num_plugins',
#  'num_unknown_packages',
#  'num_validators',
#  'object_version',
#  'package_name',
#  'package_version',
#  'prefix',
#  'prependStringToAllIdentifiers',
#  'printErrors',
#  'removeFromParentAndDelete',
#  'removeTopLevelAnnotationElement',
#  'renameMetaIdRefs',
#  'renameSIdRefs',
#  'renameUnitSIdRefs',
#  'replaceSIDWithFunction',
#  'replaceTopLevelAnnotationElement',
#  'sbml_namespaces',
#  'sbml_namespaces_and_own',
#  'sbo_term',
#  'sbo_term_as_url',
#  'sbo_term_id',
#  'setAnnotation',
#  'setApplicableValidators',
#  'setConsistencyChecks',
#  'setConsistencyChecksForConversion',
#  'setConversionValidators',
#  'setId',
#  'setIdAttribute',
#  'setLevelAndVersion',
#  'setLocationURI',
#  'setMetaId',
#  'setModel',
#  'setModelHistory',
#  'setName',
#  'setNamespaces',
#  'setNotes',
#  'setPackageRequired',
#  'setPkgRequired',
#  'setSBMLNamespacesAndOwn',
#  'setSBOTerm',
#  'this',
#  'toSBML',
#  'toXMLNode',
#  'transformIdentifiers',
#  'type_code',
#  'unsetAnnotation',
#  'unsetCVTerms',
#  'unsetId',
#  'unsetIdAttribute',
#  'unsetMetaId',
#  'unsetModelHistory',
#  'unsetName',
#  'unsetNotes',
#  'unsetSBOTerm',
#  'unsetUserData',
#  'updateSBMLNamespace',
#  'uri',
#  'validateSBML',
#  'version',
#  'writeExtensionElements']

# %%
print_model.print_model(model)
# Out:
# <Model Rohwer2001_Sucrose "Rohwer2001_Sucrose">
# reaction 0: Fruex -> Fru;
# reaction 1: Glcex -> Glc;
# reaction 2: ATP + Glc -> HexP + ADP;
# reaction 3: Fru + ATP -> HexP + ADP;
# reaction 4: Fru + ATP -> HexP + ADP;
# reaction 5: HexP -> UDP + Suc6P;
# reaction 6: Suc6P -> Suc + phos;
# reaction 7: HexP + Fru -> Suc + UDP;
# reaction 8: Suc -> Fru + Glc;
# reaction 9: HexP -> glycolysis;
# reaction 10: Suc -> Sucvac;

# %%
reaction = model.getReaction(0)
type(reaction.getReactant(0))
# Out:
# tesbml.libsbml.SpeciesReference

# %%
generator = simple_sbml.biomodelIterator(initial=98, final=98)
for idx, model in generator:
    print ("\n%s" % print_model.print_model(model))
# Out:
# <Model Goldbeter1990_CalciumSpike_CICR "Goldbeter1990_CalciumSpike_CICR">
# reaction 0:  -> Z;
# reaction 1:  -> Z;
# reaction 2: Z -> Y;
# reaction 3: Y -> Z;
# reaction 4: Y -> Z;
# reaction 5: Z -> ;
#
# None

# %%
# Iterate over species
generator = simple_sbml.biomodelIterator(final=50)
for idx, model in generator:
    print ("\n%s" % print_model.print_model(model))
# Out:
# <Model BIOMD0000000001 "Edelstein1996 - EPSP ACh event">
# reaction 0: B -> BL;
# reaction 1: BL -> BLL;
# reaction 2: BLL -> ALL;
# reaction 3: A -> AL;
# reaction 4: AL -> ALL;
# reaction 5: B -> A;
# reaction 6: BL -> AL;
# reaction 7: I -> IL;
# reaction 8: IL -> ILL;
# reaction 9: A -> I;
# reaction 10: AL -> IL;
# reaction 11: ALL -> ILL;
# reaction 12: D -> DL;
# reaction 13: DL -> DLL;
# reaction 14: I -> D;
# reaction 15: IL -> DL;
# reaction 16: ILL -> DLL;
#
# None
# <Model BIOMD0000000002 "Edelstein1996 - EPSP ACh species">
# reaction 0: B + L -> BL;
# reaction 1: BL + L -> BLL;
# reaction 2: BLL -> ALL;
# reaction 3: A + L -> AL;
# reaction 4: AL + L -> ALL;
# reaction 5: B -> A;
# reaction 6: BL -> AL;
# reaction 7: I + L -> IL;
# reaction 8: IL + L -> ILL;
# reaction 9: A -> I;
# reaction 10: AL -> IL;
# reaction 11: ALL -> ILL;
# reaction 12: D + L -> DL;
# reaction 13: DL + L -> DLL;
# reaction 14: I -> D;
# reaction 15: IL -> DL;
# reaction 16: ILL -> DLL;
#
# None
# <Model BIOMD0000000003 "Goldbeter1991 - Min Mit Oscil">
# reaction 0:  -> C;
# reaction 1: C -> ;
# reaction 2: C -> ;
# reaction 3:  -> M;
# reaction 4: M -> ;
# reaction 5:  -> X;
# reaction 6: X -> ;
#
# None
# <Model BIOMD0000000004 "Goldbeter1991 - Min Mit Oscil, Expl Inact">
# reaction 0:  -> C;
# reaction 1: C -> ;
# reaction 2: C -> ;
# reaction 3: MI -> M;
# reaction 4: M -> MI;
# reaction 5: XI -> X;
# reaction 6: X -> XI;
#
# None
# <Model BIOMD0000000005 "Tyson1991 - Cell Cycle 6 var">
# reaction 0: M -> C2 + YP;
# reaction 1: C2 -> CP;
# reaction 2: CP -> C2;
# reaction 3: CP + Y -> pM;
# reaction 4: M -> pM;
# reaction 5: EmptySet -> Y;
# reaction 6: Y -> EmptySet;
# reaction 7: YP -> EmptySet;
# reaction 8: pM -> M;
#
# None
# <Model BIOMD0000000006 "Tyson1991 - Cell Cycle 2 var">
# reaction 0: EmptySet -> z;
# reaction 1: u -> EmptySet;
# reaction 2: z -> u;
#
# None
# <Model BIOMD0000000007 "Novak1997 - Cell Cycle">
# reaction 0:  -> G2K;
# reaction 1:  -> G1K;
# reaction 2: G2K -> PG2;
# reaction 3: G2K + R -> G2R;
# reaction 4: PG2 + R -> PG2R;
# reaction 5: G2R -> G2K;
# reaction 6: R -> ;
# reaction 7: PG2R -> PG2;
# reaction 8: G1R -> G1K;
# reaction 9: G2K -> ;
# reaction 10: PG2 -> ;
# reaction 11: G1K -> ;
# reaction 12: PG2R -> R;
# reaction 13: G2R -> R;
# reaction 14: G1R -> R;
# reaction 15: G1K + R -> G1R;
# reaction 16: G2R -> R;
# reaction 17: PG2R -> R;
# reaction 18:  -> R;
# reaction 19: R -> ;
# reaction 20: IEB -> IE;
# reaction 21: UbEB -> UbE;
# reaction 22: UbE2B -> UbE2;
# reaction 23: Wee1B -> Wee1;
# reaction 24: Cdc25B -> Cdc25;
#
# None
# <Model BIOMD0000000008 "Gardner1998 - Cell Cycle Goldbeter">
# reaction 0:  -> C;
# reaction 1: C -> ;
# reaction 2: C -> ;
# reaction 3:  -> M;
# reaction 4: M -> ;
# reaction 5:  -> X;
# reaction 6: X -> ;
# reaction 7: C + Y -> Z;
# reaction 8: Z -> C + Y;
# reaction 9: Z -> C;
# reaction 10: Z -> Y;
# reaction 11:  -> Y;
# reaction 12: Y -> ;
#
# None
# <Model BIOMD0000000009 "Huang1996 - Ultrasensitivity in MAPK cascade">
# reaction 0: KKK + E1 -> E1_KKK;
# reaction 1: E1_KKK -> E1 + P_KKK;
# reaction 2: P_KKK + E2 -> E2_P_KKK;
# reaction 3: E2_P_KKK -> E2 + KKK;
# reaction 4: KK + P_KKK -> P_KKK_KK;
# reaction 5: P_KKK_KK -> P_KK + P_KKK;
# reaction 6: P_KK + KKPase -> KKPase_P_KK;
# reaction 7: KKPase_P_KK -> KK + KKPase;
# reaction 8: P_KK + P_KKK -> P_KKK_P_KK;
# reaction 9: P_KKK_P_KK -> PP_KK + P_KKK;
# reaction 10: PP_KK + KKPase -> KKPase_PP_KK;
# reaction 11: KKPase_PP_KK -> P_KK + KKPase;
# reaction 12: K + PP_KK -> PP_KK_K;
# reaction 13: PP_KK_K -> P_K + PP_KK;
# reaction 14: P_K + KPase -> KPase_P_K;
# reaction 15: KPase_P_K -> K + KPase;
# reaction 16: P_K + PP_KK -> PP_KK_P_K;
# reaction 17: PP_KK_P_K -> PP_KK + PP_K;
# reaction 18: PP_K + KPase -> KPase_PP_K;
# reaction 19: KPase_PP_K -> P_K + KPase;
#
# None
# <Model BIOMD0000000010 "Kholodenko2000 - Ultrasensitivity and negative feedback bring oscillations in MAPK cascade">
# reaction 0: MKKK -> MKKK_P;
# reaction 1: MKKK_P -> MKKK;
# reaction 2: MKK -> MKK_P;
# reaction 3: MKK_P -> MKK_PP;
# reaction 4: MKK_PP -> MKK_P;
# reaction 5: MKK_P -> MKK;
# reaction 6: MAPK -> MAPK_P;
# reaction 7: MAPK_P -> MAPK_PP;
# reaction 8: MAPK_PP -> MAPK_P;
# reaction 9: MAPK_P -> MAPK;
#
# None
# <Model MAPK_in_Solution "Levchenko2000_MAPK_noScaffold">
# reaction 0: RAF + RAFK -> RAFRAFK;
# reaction 1: RAFRAFK -> RAF + RAFK;
# reaction 2: RAFRAFK -> RAFK + RAFp;
# reaction 3: RAFp + RAFPH -> RAFpRAFPH;
# reaction 4: RAFpRAFPH -> RAFp + RAFPH;
# reaction 5: RAFpRAFPH -> RAF + RAFPH;
# reaction 6: MEK + RAFp -> MEKRAFp;
# reaction 7: MEKRAFp -> MEK + RAFp;
# reaction 8: MEKRAFp -> MEKp + RAFp;
# reaction 9: MEKp + MEKPH -> MEKpMEKPH;
# reaction 10: MEKpMEKPH -> MEKp + MEKPH;
# reaction 11: MEKpMEKPH -> MEK + MEKPH;
# reaction 12: MEKp + RAFp -> MEKpRAFp;
# reaction 13: MEKpRAFp -> MEKp + RAFp;
# reaction 14: MEKpRAFp -> MEKpp + RAFp;
# reaction 15: MEKPH + MEKpp -> MEKppMEKPH;
# reaction 16: MEKppMEKPH -> MEKPH + MEKpp;
# reaction 17: MEKppMEKPH -> MEKp + MEKPH;
# reaction 18: MAPK + MEKpp -> MAPKMEKpp;
# reaction 19: MAPKMEKpp -> MAPK + MEKpp;
# reaction 20: MAPKMEKpp -> MAPKp + MEKpp;
# reaction 21: MAPKp + MAPKPH -> MAPKpMAPKPH;
# reaction 22: MAPKpMAPKPH -> MAPKp + MAPKPH;
# reaction 23: MAPKpMAPKPH -> MAPK + MAPKPH;
# reaction 24: MAPKp + MEKpp -> MAPKpMEKpp;
# reaction 25: MAPKpMEKpp -> MAPKp + MEKpp;
# reaction 26: MAPKpMEKpp -> MAPKpp + MEKpp;
# reaction 27: MAPKPH + MAPKpp -> MAPKppMAPKPH;
# reaction 28: MAPKppMAPKPH -> MAPKPH + MAPKpp;
# reaction 29: MAPKppMAPKPH -> MAPKp + MAPKPH;
#
# None
# <Model BIOMD0000000012 "Elowitz2000 - Repressilator">
# reaction 0: X -> ;
# reaction 1: Y -> ;
# reaction 2: Z -> ;
# reaction 3:  -> PX;
# reaction 4:  -> PY;
# reaction 5:  -> PZ;
# reaction 6: PX -> ;
# reaction 7: PY -> ;
# reaction 8: PZ -> ;
# reaction 9:  -> X;
# reaction 10:  -> Y;
# reaction 11:  -> Z;
#
# None
# <Model untitled "Poolman2004_CalvinCycle">
# reaction 0: RuBP_ch + x_CO2 -> PGA_ch;
# reaction 1: PGA_ch + ATP_ch -> BPGA_ch + ADP_ch;
# reaction 2: x_NADPH_ch + BPGA_ch + x_Proton_ch -> x_NADP_ch + GAP_ch + Pi_ch;
# reaction 3: GAP_ch -> DHAP_ch;
# reaction 4: GAP_ch + DHAP_ch -> FBP_ch;
# reaction 5: FBP_ch -> F6P_ch + Pi_ch;
# reaction 6: GAP_ch + F6P_ch -> X5P_ch + E4P_ch;
# reaction 7: DHAP_ch + E4P_ch -> SBP_ch;
# reaction 8: SBP_ch -> Pi_ch + S7P_ch;
# reaction 9: S7P_ch + GAP_ch -> R5P_ch + X5P_ch;
# reaction 10: R5P_ch -> Ru5P_ch;
# reaction 11: X5P_ch -> Ru5P_ch;
# reaction 12: Ru5P_ch + ATP_ch -> RuBP_ch + ADP_ch;
# reaction 13: F6P_ch -> G6P_ch;
# reaction 14: G6P_ch -> G1P_ch;
# reaction 15: Pi_ch + ADP_ch -> ATP_ch;
# reaction 16: ATP_ch + G1P_ch -> x_Starch_ch + ADP_ch + Pi_ch;
# reaction 17: x_Starch_ch + Pi_ch -> G1P_ch;
# reaction 18: x_Pi_cyt + DHAP_ch -> x_DHAP_cyt + Pi_ch;
# reaction 19: x_Pi_cyt + PGA_ch -> x_PGA_cyt + Pi_ch;
# reaction 20: x_Pi_cyt + GAP_ch -> x_GAP_cyt + Pi_ch;
#
# None
# <Model MAPK_in_Scaffold "Levchenko2000_MAPK_Scaffold">
# reaction 0: RAFK + K_3_0 -> K_RAFK_3_0;
# reaction 1: K_RAFK_3_0 -> RAFK + K_3_0;
# reaction 2: K_RAFK_3_0 -> RAFK + K_3_1;
# reaction 3: RAFP + K_3_1 -> K_RAFP_3_1;
# reaction 4: K_RAFP_3_1 -> RAFP + K_3_1;
# reaction 5: K_RAFP_3_1 -> RAFP + K_3_0;
# reaction 6: K_2_0 + K_3_1 -> K_K_2_0_3_1;
# reaction 7: K_K_2_0_3_1 -> K_2_0 + K_3_1;
# reaction 8: K_K_2_0_3_1 -> K_2_1 + K_3_1;
# reaction 9: MEKP + K_2_1 -> K_MEKP_2_1;
# reaction 10: K_MEKP_2_1 -> MEKP + K_2_1;
# reaction 11: K_MEKP_2_1 -> MEKP + K_2_0;
# reaction 12: K_2_1 + K_3_1 -> K_K_2_1_3_1;
# reaction 13: K_K_2_1_3_1 -> K_2_1 + K_3_1;
# reaction 14: K_K_2_1_3_1 -> K_2_2 + K_3_1;
# reaction 15: MEKP + K_2_2 -> K_MEKP_2_2;
# reaction 16: K_MEKP_2_2 -> MEKP + K_2_2;
# reaction 17: K_MEKP_2_2 -> MEKP + K_2_1;
# reaction 18: K_1_0 + K_2_2 -> K_K_1_0_2_2;
# reaction 19: K_K_1_0_2_2 -> K_1_0 + K_2_2;
# reaction 20: K_K_1_0_2_2 -> K_1_1 + K_2_2;
# reaction 21: MAPKP + K_1_1 -> K_MAPKP_1_1;
# reaction 22: K_MAPKP_1_1 -> MAPKP + K_1_1;
# reaction 23: K_MAPKP_1_1 -> MAPKP + K_1_0;
# reaction 24: K_1_1 + K_2_2 -> K_K_1_1_2_2;
# reaction 25: K_K_1_1_2_2 -> K_1_1 + K_2_2;
# reaction 26: K_K_1_1_2_2 -> K_1_2 + K_2_2;
# reaction 27: MAPKP + K_1_2 -> K_MAPKP_1_2;
# reaction 28: K_MAPKP_1_2 -> MAPKP + K_1_2;
# reaction 29: K_MAPKP_1_2 -> MAPKP + K_1_1;
# reaction 30: K_1_0 + S_m1_m1_m1 -> S_0_m1_m1;
# reaction 31: S_0_m1_m1 -> K_1_0 + S_m1_m1_m1;
# reaction 32: K_1_0 + S_m1_m1_0 -> S_0_m1_0;
# reaction 33: S_0_m1_0 -> K_1_0 + S_m1_m1_0;
# reaction 34: K_1_0 + S_m1_m1_1 -> S_0_m1_1;
# reaction 35: S_0_m1_1 -> K_1_0 + S_m1_m1_1;
# reaction 36: K_1_0 + S_m1_0_m1 -> S_0_0_m1;
# reaction 37: S_0_0_m1 -> K_1_0 + S_m1_0_m1;
# reaction 38: K_1_0 + S_m1_0_0 -> S_0_0_0;
# reaction 39: S_0_0_0 -> K_1_0 + S_m1_0_0;
# reaction 40: K_1_0 + S_m1_0_1 -> S_0_0_1;
# reaction 41: S_0_0_1 -> K_1_0 + S_m1_0_1;
# reaction 42: K_1_0 + S_m1_1_m1 -> S_0_1_m1;
# reaction 43: S_0_1_m1 -> K_1_0 + S_m1_1_m1;
# reaction 44: K_1_0 + S_m1_1_0 -> S_0_1_0;
# reaction 45: S_0_1_0 -> K_1_0 + S_m1_1_0;
# reaction 46: K_1_0 + S_m1_1_1 -> S_0_1_1;
# reaction 47: S_0_1_1 -> K_1_0 + S_m1_1_1;
# reaction 48: K_1_0 + S_m1_2_m1 -> S_0_2_m1;
# reaction 49: S_0_2_m1 -> K_1_0 + S_m1_2_m1;
# reaction 50: K_1_0 + S_m1_2_0 -> S_0_2_0;
# reaction 51: S_0_2_0 -> K_1_0 + S_m1_2_0;
# reaction 52: K_1_0 + S_m1_2_1 -> S_0_2_1;
# reaction 53: S_0_2_1 -> K_1_0 + S_m1_2_1;
# reaction 54: K_1_1 + S_m1_m1_m1 -> S_1_m1_m1;
# reaction 55: S_1_m1_m1 -> K_1_1 + S_m1_m1_m1;
# reaction 56: K_1_1 + S_m1_m1_0 -> S_1_m1_0;
# reaction 57: S_1_m1_0 -> K_1_1 + S_m1_m1_0;
# reaction 58: K_1_1 + S_m1_m1_1 -> S_1_m1_1;
# reaction 59: S_1_m1_1 -> K_1_1 + S_m1_m1_1;
# reaction 60: K_1_1 + S_m1_0_m1 -> S_1_0_m1;
# reaction 61: S_1_0_m1 -> K_1_1 + S_m1_0_m1;
# reaction 62: K_1_1 + S_m1_0_0 -> S_1_0_0;
# reaction 63: S_1_0_0 -> K_1_1 + S_m1_0_0;
# reaction 64: K_1_1 + S_m1_0_1 -> S_1_0_1;
# reaction 65: S_1_0_1 -> K_1_1 + S_m1_0_1;
# reaction 66: K_1_1 + S_m1_1_m1 -> S_1_1_m1;
# reaction 67: S_1_1_m1 -> K_1_1 + S_m1_1_m1;
# reaction 68: K_1_1 + S_m1_1_0 -> S_1_1_0;
# reaction 69: S_1_1_0 -> K_1_1 + S_m1_1_0;
# reaction 70: K_1_1 + S_m1_1_1 -> S_1_1_1;
# reaction 71: S_1_1_1 -> K_1_1 + S_m1_1_1;
# reaction 72: K_1_1 + S_m1_2_m1 -> S_1_2_m1;
# reaction 73: S_1_2_m1 -> K_1_1 + S_m1_2_m1;
# reaction 74: K_1_1 + S_m1_2_0 -> S_1_2_0;
# reaction 75: S_1_2_0 -> K_1_1 + S_m1_2_0;
# reaction 76: K_1_1 + S_m1_2_1 -> S_1_2_1;
# reaction 77: S_1_2_1 -> K_1_1 + S_m1_2_1;
# reaction 78: K_1_2 + S_m1_m1_m1 -> S_2_m1_m1;
# reaction 79: S_2_m1_m1 -> K_1_2 + S_m1_m1_m1;
# reaction 80: K_1_2 + S_m1_m1_0 -> S_2_m1_0;
# reaction 81: S_2_m1_0 -> K_1_2 + S_m1_m1_0;
# reaction 82: K_1_2 + S_m1_m1_1 -> S_2_m1_1;
# reaction 83: S_2_m1_1 -> K_1_2 + S_m1_m1_1;
# reaction 84: K_1_2 + S_m1_0_m1 -> S_2_0_m1;
# reaction 85: S_2_0_m1 -> K_1_2 + S_m1_0_m1;
# reaction 86: K_1_2 + S_m1_0_0 -> S_2_0_0;
# reaction 87: S_2_0_0 -> K_1_2 + S_m1_0_0;
# reaction 88: K_1_2 + S_m1_0_1 -> S_2_0_1;
# reaction 89: S_2_0_1 -> K_1_2 + S_m1_0_1;
# reaction 90: K_1_2 + S_m1_1_m1 -> S_2_1_m1;
# reaction 91: S_2_1_m1 -> K_1_2 + S_m1_1_m1;
# reaction 92: K_1_2 + S_m1_1_0 -> S_2_1_0;
# reaction 93: S_2_1_0 -> K_1_2 + S_m1_1_0;
# reaction 94: K_1_2 + S_m1_1_1 -> S_2_1_1;
# reaction 95: S_2_1_1 -> K_1_2 + S_m1_1_1;
# reaction 96: K_1_2 + S_m1_2_m1 -> S_2_2_m1;
# reaction 97: S_2_2_m1 -> K_1_2 + S_m1_2_m1;
# reaction 98: K_1_2 + S_m1_2_0 -> S_2_2_0;
# reaction 99: S_2_2_0 -> K_1_2 + S_m1_2_0;
# reaction 100: K_1_2 + S_m1_2_1 -> S_2_2_1;
# reaction 101: S_2_2_1 -> K_1_2 + S_m1_2_1;
# reaction 102: K_2_0 + S_m1_m1_m1 -> S_m1_0_m1;
# reaction 103: S_m1_0_m1 -> K_2_0 + S_m1_m1_m1;
# reaction 104: K_2_0 + S_m1_m1_0 -> S_m1_0_0;
# reaction 105: S_m1_0_0 -> K_2_0 + S_m1_m1_0;
# reaction 106: K_2_0 + S_m1_m1_1 -> S_m1_0_1;
# reaction 107: S_m1_0_1 -> K_2_0 + S_m1_m1_1;
# reaction 108: K_2_1 + S_m1_m1_m1 -> S_m1_1_m1;
# reaction 109: S_m1_1_m1 -> K_2_1 + S_m1_m1_m1;
# reaction 110: K_2_1 + S_m1_m1_0 -> S_m1_1_0;
# reaction 111: S_m1_1_0 -> K_2_1 + S_m1_m1_0;
# reaction 112: K_2_1 + S_m1_m1_1 -> S_m1_1_1;
# reaction 113: S_m1_1_1 -> K_2_1 + S_m1_m1_1;
# reaction 114: K_2_2 + S_m1_m1_m1 -> S_m1_2_m1;
# reaction 115: S_m1_2_m1 -> K_2_2 + S_m1_m1_m1;
# reaction 116: K_2_2 + S_m1_m1_0 -> S_m1_2_0;
# reaction 117: S_m1_2_0 -> K_2_2 + S_m1_m1_0;
# reaction 118: K_2_2 + S_m1_m1_1 -> S_m1_2_1;
# reaction 119: S_m1_2_1 -> K_2_2 + S_m1_m1_1;
# reaction 120: K_2_0 + S_0_m1_m1 -> S_0_0_m1;
# reaction 121: S_0_0_m1 -> K_2_0 + S_0_m1_m1;
# reaction 122: K_2_0 + S_0_m1_0 -> S_0_0_0;
# reaction 123: S_0_0_0 -> K_2_0 + S_0_m1_0;
# reaction 124: K_2_0 + S_0_m1_1 -> S_0_0_1;
# reaction 125: S_0_0_1 -> K_2_0 + S_0_m1_1;
# reaction 126: K_2_1 + S_0_m1_m1 -> S_0_1_m1;
# reaction 127: S_0_1_m1 -> K_2_1 + S_0_m1_m1;
# reaction 128: K_2_1 + S_0_m1_0 -> S_0_1_0;
# reaction 129: S_0_1_0 -> K_2_1 + S_0_m1_0;
# reaction 130: K_2_1 + S_0_m1_1 -> S_0_1_1;
# reaction 131: S_0_1_1 -> K_2_1 + S_0_m1_1;
# reaction 132: K_2_2 + S_0_m1_m1 -> S_0_2_m1;
# reaction 133: S_0_2_m1 -> K_2_2 + S_0_m1_m1;
# reaction 134: K_2_2 + S_0_m1_0 -> S_0_2_0;
# reaction 135: S_0_2_0 -> K_2_2 + S_0_m1_0;
# reaction 136: K_2_2 + S_0_m1_1 -> S_0_2_1;
# reaction 137: S_0_2_1 -> K_2_2 + S_0_m1_1;
# reaction 138: K_2_0 + S_1_m1_m1 -> S_1_0_m1;
# reaction 139: S_1_0_m1 -> K_2_0 + S_1_m1_m1;
# reaction 140: K_2_0 + S_1_m1_0 -> S_1_0_0;
# reaction 141: S_1_0_0 -> K_2_0 + S_1_m1_0;
# reaction 142: K_2_0 + S_1_m1_1 -> S_1_0_1;
# reaction 143: S_1_0_1 -> K_2_0 + S_1_m1_1;
# reaction 144: K_2_1 + S_1_m1_m1 -> S_1_1_m1;
# reaction 145: S_1_1_m1 -> K_2_1 + S_1_m1_m1;
# reaction 146: K_2_1 + S_1_m1_0 -> S_1_1_0;
# reaction 147: S_1_1_0 -> K_2_1 + S_1_m1_0;
# reaction 148: K_2_1 + S_1_m1_1 -> S_1_1_1;
# reaction 149: S_1_1_1 -> K_2_1 + S_1_m1_1;
# reaction 150: K_2_2 + S_1_m1_m1 -> S_1_2_m1;
# reaction 151: S_1_2_m1 -> K_2_2 + S_1_m1_m1;
# reaction 152: K_2_2 + S_1_m1_0 -> S_1_2_0;
# reaction 153: S_1_2_0 -> K_2_2 + S_1_m1_0;
# reaction 154: K_2_2 + S_1_m1_1 -> S_1_2_1;
# reaction 155: S_1_2_1 -> K_2_2 + S_1_m1_1;
# reaction 156: K_2_0 + S_2_m1_m1 -> S_2_0_m1;
# reaction 157: S_2_0_m1 -> K_2_0 + S_2_m1_m1;
# reaction 158: K_2_0 + S_2_m1_0 -> S_2_0_0;
# reaction 159: S_2_0_0 -> K_2_0 + S_2_m1_0;
# reaction 160: K_2_0 + S_2_m1_1 -> S_2_0_1;
# reaction 161: S_2_0_1 -> K_2_0 + S_2_m1_1;
# reaction 162: K_2_1 + S_2_m1_m1 -> S_2_1_m1;
# reaction 163: S_2_1_m1 -> K_2_1 + S_2_m1_m1;
# reaction 164: K_2_1 + S_2_m1_0 -> S_2_1_0;
# reaction 165: S_2_1_0 -> K_2_1 + S_2_m1_0;
# reaction 166: K_2_1 + S_2_m1_1 -> S_2_1_1;
# reaction 167: S_2_1_1 -> K_2_1 + S_2_m1_1;
# reaction 168: K_2_2 + S_2_m1_m1 -> S_2_2_m1;
# reaction 169: S_2_2_m1 -> K_2_2 + S_2_m1_m1;
# reaction 170: K_2_2 + S_2_m1_0 -> S_2_2_0;
# reaction 171: S_2_2_0 -> K_2_2 + S_2_m1_0;
# reaction 172: K_2_2 + S_2_m1_1 -> S_2_2_1;
# reaction 173: S_2_2_1 -> K_2_2 + S_2_m1_1;
# reaction 174: K_3_0 + S_m1_m1_m1 -> S_m1_m1_0;
# reaction 175: S_m1_m1_0 -> K_3_0 + S_m1_m1_m1;
# reaction 176: K_3_1 + S_m1_m1_m1 -> S_m1_m1_1;
# reaction 177: S_m1_m1_1 -> K_3_1 + S_m1_m1_m1;
# reaction 178: K_3_0 + S_m1_0_m1 -> S_m1_0_0;
# reaction 179: S_m1_0_0 -> K_3_0 + S_m1_0_m1;
# reaction 180: K_3_1 + S_m1_0_m1 -> S_m1_0_1;
# reaction 181: S_m1_0_1 -> K_3_1 + S_m1_0_m1;
# reaction 182: K_3_0 + S_m1_1_m1 -> S_m1_1_0;
# reaction 183: S_m1_1_0 -> K_3_0 + S_m1_1_m1;
# reaction 184: K_3_1 + S_m1_1_m1 -> S_m1_1_1;
# reaction 185: S_m1_1_1 -> K_3_1 + S_m1_1_m1;
# reaction 186: K_3_0 + S_m1_2_m1 -> S_m1_2_0;
# reaction 187: S_m1_2_0 -> K_3_0 + S_m1_2_m1;
# reaction 188: K_3_1 + S_m1_2_m1 -> S_m1_2_1;
# reaction 189: S_m1_2_1 -> K_3_1 + S_m1_2_m1;
# reaction 190: K_3_0 + S_0_m1_m1 -> S_0_m1_0;
# reaction 191: S_0_m1_0 -> K_3_0 + S_0_m1_m1;
# reaction 192: K_3_1 + S_0_m1_m1 -> S_0_m1_1;
# reaction 193: S_0_m1_1 -> K_3_1 + S_0_m1_m1;
# reaction 194: K_3_0 + S_0_0_m1 -> S_0_0_0;
# reaction 195: S_0_0_0 -> K_3_0 + S_0_0_m1;
# reaction 196: K_3_1 + S_0_0_m1 -> S_0_0_1;
# reaction 197: S_0_0_1 -> K_3_1 + S_0_0_m1;
# reaction 198: K_3_0 + S_0_1_m1 -> S_0_1_0;
# reaction 199: S_0_1_0 -> K_3_0 + S_0_1_m1;
# reaction 200: K_3_1 + S_0_1_m1 -> S_0_1_1;
# reaction 201: S_0_1_1 -> K_3_1 + S_0_1_m1;
# reaction 202: K_3_0 + S_0_2_m1 -> S_0_2_0;
# reaction 203: S_0_2_0 -> K_3_0 + S_0_2_m1;
# reaction 204: K_3_1 + S_0_2_m1 -> S_0_2_1;
# reaction 205: S_0_2_1 -> K_3_1 + S_0_2_m1;
# reaction 206: K_3_0 + S_1_m1_m1 -> S_1_m1_0;
# reaction 207: S_1_m1_0 -> K_3_0 + S_1_m1_m1;
# reaction 208: K_3_1 + S_1_m1_m1 -> S_1_m1_1;
# reaction 209: S_1_m1_1 -> K_3_1 + S_1_m1_m1;
# reaction 210: K_3_0 + S_1_0_m1 -> S_1_0_0;
# reaction 211: S_1_0_0 -> K_3_0 + S_1_0_m1;
# reaction 212: K_3_1 + S_1_0_m1 -> S_1_0_1;
# reaction 213: S_1_0_1 -> K_3_1 + S_1_0_m1;
# reaction 214: K_3_0 + S_1_1_m1 -> S_1_1_0;
# reaction 215: S_1_1_0 -> K_3_0 + S_1_1_m1;
# reaction 216: K_3_1 + S_1_1_m1 -> S_1_1_1;
# reaction 217: S_1_1_1 -> K_3_1 + S_1_1_m1;
# reaction 218: K_3_0 + S_1_2_m1 -> S_1_2_0;
# reaction 219: S_1_2_0 -> K_3_0 + S_1_2_m1;
# reaction 220: K_3_1 + S_1_2_m1 -> S_1_2_1;
# reaction 221: S_1_2_1 -> K_3_1 + S_1_2_m1;
# reaction 222: K_3_0 + S_2_m1_m1 -> S_2_m1_0;
# reaction 223: S_2_m1_0 -> K_3_0 + S_2_m1_m1;
# reaction 224: K_3_1 + S_2_m1_m1 -> S_2_m1_1;
# reaction 225: S_2_m1_1 -> K_3_1 + S_2_m1_m1;
# reaction 226: K_3_0 + S_2_0_m1 -> S_2_0_0;
# reaction 227: S_2_0_0 -> K_3_0 + S_2_0_m1;
# reaction 228: K_3_1 + S_2_0_m1 -> S_2_0_1;
# reaction 229: S_2_0_1 -> K_3_1 + S_2_0_m1;
# reaction 230: K_3_0 + S_2_1_m1 -> S_2_1_0;
# reaction 231: S_2_1_0 -> K_3_0 + S_2_1_m1;
# reaction 232: K_3_1 + S_2_1_m1 -> S_2_1_1;
# reaction 233: S_2_1_1 -> K_3_1 + S_2_1_m1;
# reaction 234: K_3_0 + S_2_2_m1 -> S_2_2_0;
# reaction 235: S_2_2_0 -> K_3_0 + S_2_2_m1;
# reaction 236: K_3_1 + S_2_2_m1 -> S_2_2_1;
# reaction 237: S_2_2_1 -> K_3_1 + S_2_2_m1;
# reaction 238: S_0_2_m1 -> S_1_2_m1;
# reaction 239: S_0_2_0 -> S_1_2_0;
# reaction 240: S_0_2_1 -> S_1_2_1;
# reaction 241: S_1_2_m1 -> S_2_2_m1;
# reaction 242: S_1_2_0 -> S_2_2_0;
# reaction 243: S_1_2_1 -> S_2_2_1;
# reaction 244: S_m1_0_1 -> S_m1_1_1;
# reaction 245: S_m1_1_1 -> S_m1_2_1;
# reaction 246: S_0_0_1 -> S_0_1_1;
# reaction 247: S_0_1_1 -> S_0_2_1;
# reaction 248: S_1_0_1 -> S_1_1_1;
# reaction 249: S_1_1_1 -> S_1_2_1;
# reaction 250: S_2_0_1 -> S_2_1_1;
# reaction 251: S_2_1_1 -> S_2_2_1;
# reaction 252: RAFK + S_m1_m1_0 -> S_RAFK_m1_m1_0;
# reaction 253: S_RAFK_m1_m1_0 -> RAFK + S_m1_m1_0;
# reaction 254: S_RAFK_m1_m1_0 -> RAFK + S_m1_m1_1;
# reaction 255: RAFK + S_m1_0_0 -> S_RAFK_m1_0_0;
# reaction 256: S_RAFK_m1_0_0 -> RAFK + S_m1_0_0;
# reaction 257: S_RAFK_m1_0_0 -> RAFK + S_m1_0_1;
# reaction 258: RAFK + S_m1_1_0 -> S_RAFK_m1_1_0;
# reaction 259: S_RAFK_m1_1_0 -> RAFK + S_m1_1_0;
# reaction 260: S_RAFK_m1_1_0 -> RAFK + S_m1_1_1;
# reaction 261: RAFK + S_m1_2_0 -> S_RAFK_m1_2_0;
# reaction 262: S_RAFK_m1_2_0 -> RAFK + S_m1_2_0;
# reaction 263: S_RAFK_m1_2_0 -> RAFK + S_m1_2_1;
# reaction 264: RAFK + S_0_m1_0 -> S_RAFK_0_m1_0;
# reaction 265: S_RAFK_0_m1_0 -> RAFK + S_0_m1_0;
# reaction 266: S_RAFK_0_m1_0 -> RAFK + S_0_m1_1;
# reaction 267: RAFK + S_0_0_0 -> S_RAFK_0_0_0;
# reaction 268: S_RAFK_0_0_0 -> RAFK + S_0_0_0;
# reaction 269: S_RAFK_0_0_0 -> RAFK + S_0_0_1;
# reaction 270: RAFK + S_0_1_0 -> S_RAFK_0_1_0;
# reaction 271: S_RAFK_0_1_0 -> RAFK + S_0_1_0;
# reaction 272: S_RAFK_0_1_0 -> RAFK + S_0_1_1;
# reaction 273: RAFK + S_0_2_0 -> S_RAFK_0_2_0;
# reaction 274: S_RAFK_0_2_0 -> RAFK + S_0_2_0;
# reaction 275: S_RAFK_0_2_0 -> RAFK + S_0_2_1;
# reaction 276: RAFK + S_1_m1_0 -> S_RAFK_1_m1_0;
# reaction 277: S_RAFK_1_m1_0 -> RAFK + S_1_m1_0;
# reaction 278: S_RAFK_1_m1_0 -> RAFK + S_1_m1_1;
# reaction 279: RAFK + S_1_0_0 -> S_RAFK_1_0_0;
# reaction 280: S_RAFK_1_0_0 -> RAFK + S_1_0_0;
# reaction 281: S_RAFK_1_0_0 -> RAFK + S_1_0_1;
# reaction 282: RAFK + S_1_1_0 -> S_RAFK_1_1_0;
# reaction 283: S_RAFK_1_1_0 -> RAFK + S_1_1_0;
# reaction 284: S_RAFK_1_1_0 -> RAFK + S_1_1_1;
# reaction 285: RAFK + S_1_2_0 -> S_RAFK_1_2_0;
# reaction 286: S_RAFK_1_2_0 -> RAFK + S_1_2_0;
# reaction 287: S_RAFK_1_2_0 -> RAFK + S_1_2_1;
# reaction 288: RAFK + S_2_m1_0 -> S_RAFK_2_m1_0;
# reaction 289: S_RAFK_2_m1_0 -> RAFK + S_2_m1_0;
# reaction 290: S_RAFK_2_m1_0 -> RAFK + S_2_m1_1;
# reaction 291: RAFK + S_2_0_0 -> S_RAFK_2_0_0;
# reaction 292: S_RAFK_2_0_0 -> RAFK + S_2_0_0;
# reaction 293: S_RAFK_2_0_0 -> RAFK + S_2_0_1;
# reaction 294: RAFK + S_2_1_0 -> S_RAFK_2_1_0;
# reaction 295: S_RAFK_2_1_0 -> RAFK + S_2_1_0;
# reaction 296: S_RAFK_2_1_0 -> RAFK + S_2_1_1;
# reaction 297: RAFK + S_2_2_0 -> S_RAFK_2_2_0;
# reaction 298: S_RAFK_2_2_0 -> RAFK + S_2_2_0;
# reaction 299: S_RAFK_2_2_0 -> RAFK + S_2_2_1;
#
# None
# <Model BIOMD0000000015 "Curto1998 - purine metabolism">
# reaction 0: ATP -> HX;
# reaction 1: Ade -> ;
# reaction 2: dATP -> DNA;
# reaction 3: ATP -> dATP;
# reaction 4: ATP -> IMP;
# reaction 5: PRPP + Ade -> ATP;
# reaction 6: ATP -> RNA;
# reaction 7: IMP -> SAMP;
# reaction 8: SAMP -> ATP;
# reaction 9: dATP -> HX;
# reaction 10: PRPP -> IMP;
# reaction 11: dGTP -> Gua;
# reaction 12: DNA -> dATP;
# reaction 13: DNA -> dGTP;
# reaction 14: dGTP -> DNA;
# reaction 15: GTP -> dGTP;
# reaction 16: GTP -> IMP;
# reaction 17: XMP -> GTP;
# reaction 18: GTP -> Gua;
# reaction 19: Gua + PRPP -> GTP;
# reaction 20: GTP -> RNA;
# reaction 21: Gua -> Xa;
# reaction 22: HX + PRPP -> IMP;
# reaction 23: HX -> ;
# reaction 24: HX -> Xa;
# reaction 25: IMP -> XMP;
# reaction 26: IMP -> HX;
# reaction 27: ATP -> SAM;
# reaction 28: SAM -> Ade;
# reaction 29: R5P -> PRPP;
# reaction 30: PRPP -> ;
# reaction 31: RNA -> ATP;
# reaction 32: RNA -> GTP;
# reaction 33: SAM -> ATP;
# reaction 34: UA -> ;
# reaction 35: Xa -> ;
# reaction 36: Xa -> UA;
#
# None
# <Model Goldbeter1995 "Goldbeter1995_CircClock">
# reaction 0: EmptySet -> M;
# reaction 1: EmptySet -> P0;
# reaction 2: P0 -> P1;
# reaction 3: P1 -> P0;
# reaction 4: P1 -> P2;
# reaction 5: P2 -> P1;
# reaction 6: P2 -> Pn;
# reaction 7: Pn -> P2;
# reaction 8: M -> EmptySet;
# reaction 9: P2 -> EmptySet;
#
# None
# <Model Hoefnagel2002_PyruvateBranches "Hoefnagel2002_PyruvateBranches">
# reaction 0: ADP + NAD + halfglucose -> ATP + NADH + pyruvate;
# reaction 1: NADH + pyruvate -> NAD + lactate;
# reaction 2: NAD + pyruvate + CoA -> NADH + AcCoA;
# reaction 3: AcCoA + PO4 -> CoA + AcP;
# reaction 4: ADP + AcP -> ATP + Ac;
# reaction 5: NADH + AcCoA -> NAD + CoA + AcO;
# reaction 6: NADH + AcO -> NAD + EtOH;
# reaction 7: pyruvate -> AcLac;
# reaction 8: AcLac -> AcetoinIn;
# reaction 9: AcetoinIn -> AcetoinOut;
# reaction 10: NADH + AcetoinIn -> NAD + Butanediol;
# reaction 11: ATP -> ADP;
# reaction 12: NADH + O2 -> NAD;
# reaction 13: AcLac -> AcetoinIn;
#
# None
# <Model MorrisonAllegra "Morrison1989 - Folate Cycle">
# reaction 0: FH4 + serine -> CH2FH4;
# reaction 1: CH2FH4 -> FH4;
# reaction 2: FH4 + HCHO -> CH2FH4;
# reaction 3: CH2FH4 -> FH4 + HCHO;
# reaction 4: CH2FH4 + NADPH -> CH3FH4;
# reaction 5: CH3FH4 + homocysteine -> FH4;
# reaction 6: FH4 + formate + ATP -> CHOFH4;
# reaction 7: CHOFH4 + GAR -> FGAR + FH4;
# reaction 8: CHOFH4 + AICAR -> FH4;
# reaction 9: CH2FH4 + NADP -> CHOFH4;
# reaction 10: CH2FH4 + dUMP -> FH2f;
# reaction 11: FH2f -> FH4;
# reaction 12: FH2f -> FFH2;
# reaction 13: FFH2 + AICAR -> FH2f;
# reaction 14: FGAR -> AICAR;
# reaction 15: MTX1 -> MTX2;
# reaction 16: MTX2 -> MTX3;
# reaction 17: MTX3 -> MTX4;
# reaction 18: MTX4 -> MTX5;
# reaction 19: MTX2 -> MTX1;
# reaction 20: MTX3 -> MTX2;
# reaction 21: MTX4 -> MTX3;
# reaction 22: MTX5 -> MTX4;
# reaction 23: EMTX -> MTX1;
# reaction 24: MTX1 -> ;
# reaction 25: MTX2 -> ;
# reaction 26: MTX3 -> ;
# reaction 27: MTX4 -> ;
# reaction 28: MTX5 -> ;
# reaction 29: MTX1 + DHFRf -> MTX1b;
# reaction 30: MTX2 + DHFRf -> MTX2b;
# reaction 31: MTX3 + DHFRf -> MTX3b;
# reaction 32: MTX4 + DHFRf -> MTX4b;
# reaction 33: MTX5 + DHFRf -> MTX5b;
# reaction 34: MTX1b -> MTX1 + DHFRf;
# reaction 35: MTX2b -> MTX2 + DHFRf;
# reaction 36: MTX3b -> MTX3 + DHFRf;
# reaction 37: MTX4b -> MTX4 + DHFRf;
# reaction 38: MTX5b -> MTX5 + DHFRf;
# reaction 39:  -> DHFRf;
# reaction 40: DHFRf -> ;
# reaction 41:  -> FH2f;
# reaction 42: MTX1b -> MTX1;
# reaction 43: MTX2b -> MTX2;
# reaction 44: MTX3b -> MTX3;
# reaction 45: MTX4b -> MTX4;
# reaction 46: MTX5b -> MTX5;
#
# None
# <Model BIOMD0000000019 "Schoeberl2002 - EGF MAPK">
# reaction 0: x1 + x2 -> x3;
# reaction 1: x3 -> x4;
# reaction 2: x4 -> x5;
# reaction 3: x23 + x12 -> x7;
# reaction 4: x7 -> x18 + x9;
# reaction 5: x2 -> x6;
# reaction 6: x5 -> x8;
# reaction 7: x5 + x14 -> x15;
# reaction 8: x23 -> x18;
# reaction 9: x6 + x16 -> x10;
# reaction 10: x10 -> x11;
# reaction 11: x11 -> x8;
# reaction 12:  -> x2;
# reaction 13: x8 + x14 -> x17;
# reaction 14: x9 -> x12;
# reaction 15: x22 + x15 -> x23;
# reaction 16: x24 + x23 -> x25;
# reaction 17: x26 + x25 -> x27;
# reaction 18: x27 -> x28 + x25;
# reaction 19: x25 + x43 -> x29;
# reaction 20: x29 -> x25 + x26;
# reaction 21: x31 + x15 -> x32;
# reaction 22: x32 -> x33;
# reaction 23: x22 + x33 -> x34;
# reaction 24: x24 + x34 -> x35;
# reaction 25: x26 + x35 -> x36;
# reaction 26: x36 -> x35 + x28;
# reaction 27: x28 + x41 -> x42;
# reaction 28: x42 -> x43 + x45;
# reaction 29: x35 + x43 -> x37;
# reaction 30: x37 -> x35 + x26;
# reaction 31: x35 -> x15 + x38;
# reaction 32: x38 -> x40 + x30;
# reaction 33: x25 -> x15 + x30;
# reaction 34: x30 -> x24 + x22;
# reaction 35: x40 -> x31;
# reaction 36: x33 -> x15 + x40;
# reaction 37: x22 + x40 -> x39;
# reaction 38: x34 -> x15 + x39;
# reaction 39: x24 + x39 -> x38;
# reaction 40: x30 + x33 -> x35;
# reaction 41: x44 + x45 -> x46;
# reaction 42: x46 -> x41 + x44;
# reaction 43: x47 + x45 -> x48;
# reaction 44: x48 -> x49 + x45;
# reaction 45: x49 + x45 -> x50;
# reaction 46: x50 -> x51 + x45;
# reaction 47: x51 + x53 -> x52;
# reaction 48: x52 -> x49 + x53;
# reaction 49: x53 + x49 -> x54;
# reaction 50: x54 -> x47 + x53;
# reaction 51: x55 + x51 -> x56;
# reaction 52: x56 -> x51 + x57;
# reaction 53: x51 + x57 -> x58;
# reaction 54: x58 -> x59 + x51;
# reaction 55: x59 + x60 -> x61;
# reaction 56: x61 -> x57 + x60;
# reaction 57: x60 + x57 -> x62;
# reaction 58: x62 -> x55 + x60;
# reaction 59: x6 -> x86;
# reaction 60: x16 -> x13;
# reaction 61: x8 -> x87;
# reaction 62: x17 + x22 -> x18;
# reaction 63: x24 + x18 -> x19;
# reaction 64: x26 + x19 -> x20;
# reaction 65: x20 -> x69 + x19;
# reaction 66: x71 + x19 -> x21;
# reaction 67: x21 -> x19 + x26;
# reaction 68: x31 + x17 -> x63;
# reaction 69: x63 -> x64;
# reaction 70: x22 + x64 -> x65;
# reaction 71: x24 + x65 -> x66;
# reaction 72: x26 + x66 -> x67;
# reaction 73: x67 -> x66 + x69;
# reaction 74: x69 + x41 -> x70;
# reaction 75: x70 -> x71 + x72;
# reaction 76: x71 + x66 -> x68;
# reaction 77: x68 -> x66 + x26;
# reaction 78: x66 -> x17 + x38;
# reaction 79: x19 -> x17 + x30;
# reaction 80: x64 -> x17 + x40;
# reaction 81: x65 -> x17 + x39;
# reaction 82: x30 + x64 -> x66;
# reaction 83: x44 + x72 -> x73;
# reaction 84: x73 -> x41 + x44;
# reaction 85: x47 + x72 -> x74;
# reaction 86: x74 -> x75 + x72;
# reaction 87: x72 + x75 -> x76;
# reaction 88: x76 -> x72 + x77;
# reaction 89: x77 + x53 -> x78;
# reaction 90: x78 -> x75 + x53;
# reaction 91: x53 + x75 -> x79;
# reaction 92: x79 -> x47 + x53;
# reaction 93: x55 + x77 -> x80;
# reaction 94: x80 -> x81 + x77;
# reaction 95: x77 + x81 -> x82;
# reaction 96: x82 -> x83 + x77;
# reaction 97: x83 + x60 -> x84;
# reaction 98: x84 -> x81 + x60;
# reaction 99: x60 + x81 -> x85;
# reaction 100: x85 -> x55 + x60;
# reaction 101: x15 -> x17;
# reaction 102: x32 -> x63;
# reaction 103: x33 -> x64;
# reaction 104: x25 -> x19;
# reaction 105: x25 + x12 -> x88;
# reaction 106: x88 -> x9 + x19;
# reaction 107: x27 -> x20;
# reaction 108: x27 + x12 -> x89;
# reaction 109: x89 -> x9 + x20;
# reaction 110: x29 -> x21;
# reaction 111: x29 + x12 -> x90;
# reaction 112: x90 -> x9 + x21;
# reaction 113: x34 -> x65;
# reaction 114: x34 + x12 -> x91;
# reaction 115: x91 -> x9 + x65;
# reaction 116: x35 -> x66;
# reaction 117: x35 + x12 -> x92;
# reaction 118: x92 -> x9 + x66;
# reaction 119: x36 -> x67;
# reaction 120: x36 + x12 -> x93;
# reaction 121: x93 -> x9 + x67;
# reaction 122: x37 -> x68;
# reaction 123: x37 + x12 -> x94;
# reaction 124: x94 -> x68 + x9;
#
# None
# <Model hhsa_1952 "Hodgkin-Huxley1952 squid-axon">
#
# None
# <Model Leloup1999_CircClock_periodic "Leloup1999_CircClock">
# reaction 0: P0 -> P1;
# reaction 1: T0 -> T1;
# reaction 2: P1 -> P0;
# reaction 3: T1 -> T0;
# reaction 4: P1 -> P2;
# reaction 5: T1 -> T2;
# reaction 6: P2 -> P1;
# reaction 7: T2 -> T1;
# reaction 8: P0 -> ;
# reaction 9: T0 -> ;
# reaction 10: P1 -> ;
# reaction 11: T1 -> ;
# reaction 12: P2 -> ;
# reaction 13: T2 -> ;
# reaction 14: P2 + T2 -> CC;
# reaction 15: CC -> Cn;
# reaction 16: CC -> ;
# reaction 17: Cn -> ;
# reaction 18:  -> Mp;
# reaction 19:  -> Mt;
# reaction 20:  -> P0;
# reaction 21:  -> T0;
# reaction 22: Mp -> ;
# reaction 23: Mt -> ;
#
# None
# <Model Ueda2001_CircClock "Ueda2001_CircClock">
# reaction 0: EmptySet -> Perm;
# reaction 1: Perm -> EmptySet;
# reaction 2: EmptySet -> Timm;
# reaction 3: Timm -> EmptySet;
# reaction 4: EmptySet -> Clkm;
# reaction 5: Clkm -> EmptySet;
# reaction 6: CCc -> CCn;
# reaction 7: CCn -> CCc;
# reaction 8: PTn -> PTc;
# reaction 9: PTc -> PTn;
# reaction 10: species_0000012 + Clkc -> CCc;
# reaction 11: Perc + Timc -> PTc;
# reaction 12: EmptySet -> Timc;
# reaction 13: EmptySet -> Clkc;
# reaction 14: EmptySet -> Perc;
# reaction 15: Perc -> EmptySet;
# reaction 16: PTc -> EmptySet;
# reaction 17: PTn -> EmptySet;
# reaction 18: CCc -> EmptySet;
# reaction 19: Clkc -> EmptySet;
# reaction 20: CCn -> EmptySet;
# reaction 21: Timc -> EmptySet;
# reaction 22: Perm -> EmptySet;
# reaction 23: Perc -> EmptySet;
# reaction 24: Timm -> EmptySet;
# reaction 25: Timc -> EmptySet;
# reaction 26: PTc -> EmptySet;
# reaction 27: PTn -> EmptySet;
# reaction 28: Clkm -> EmptySet;
# reaction 29: Clkc -> EmptySet;
# reaction 30: CCc -> EmptySet;
# reaction 31: CCn -> EmptySet;
#
# None
# <Model Rohwer2001_Sucrose "Rohwer2001_Sucrose">
# reaction 0: Fruex -> Fru;
# reaction 1: Glcex -> Glc;
# reaction 2: ATP + Glc -> HexP + ADP;
# reaction 3: Fru + ATP -> HexP + ADP;
# reaction 4: Fru + ATP -> HexP + ADP;
# reaction 5: HexP -> UDP + Suc6P;
# reaction 6: Suc6P -> Suc + phos;
# reaction 7: HexP + Fru -> Suc + UDP;
# reaction 8: Suc -> Fru + Glc;
# reaction 9: HexP -> glycolysis;
# reaction 10: Suc -> Sucvac;
#
# None
# <Model Scheper1999 "Scheper1999_CircClock">
# reaction 0: EmptySet -> M;
# reaction 1: EmptySet -> P;
# reaction 2: M -> EmptySet;
# reaction 3: P -> EmptySet;
#
# None
# <Model Smolen2002 "Smolen2002_CircClock">
# reaction 0: EmptySet -> Per;
# reaction 1: EmptySet -> dClk;
# reaction 2: Per -> EmptySet;
# reaction 3: dClk -> EmptySet;
#
# None
# <Model Markevich2004_MAPK_orderedelementary "Markevich2004_MAPK_orderedElementary">
# reaction 0: M + MAPKK -> M_MAPKK;
# reaction 1: M_MAPKK -> Mp + MAPKK;
# reaction 2: Mp + MAPKK -> Mp_MAPKK;
# reaction 3: Mp_MAPKK -> Mpp + MAPKK;
# reaction 4: Mpp + MKP3 -> Mpp_MKP3;
# reaction 5: Mpp_MKP3 -> Mp_MKP3_dep;
# reaction 6: Mp_MKP3_dep -> Mp + MKP3;
# reaction 7: Mp + MKP3 -> Mp_MKP3;
# reaction 8: Mp_MKP3 -> M_MKP3;
# reaction 9: M_MKP3 -> M + MKP3;
#
# None
# <Model Markevich2004_MAPK_orderedMM "Markevich2004 - MAPK double phosphorylation,  ordered Michaelis-Menton">
# reaction 0: M -> Mp;
# reaction 1: Mp -> Mpp;
# reaction 2: Mpp -> Mp;
# reaction 3: Mp -> M;
#
# None
# <Model model_0000001 "Markevich2004_MAPK_phosphoRandomElementary">
# reaction 0: M + MEK -> M_MEK_Y;
# reaction 1: M_MEK_Y -> MpY + MEK;
# reaction 2: MpY + MEK -> MpY_MEK;
# reaction 3: MpY_MEK -> Mpp + MEK;
# reaction 4: M + MEK -> M_MEK_T;
# reaction 5: M_MEK_T -> MpT + MEK;
# reaction 6: MpT + MEK -> MpT_MEK;
# reaction 7: MpT_MEK -> Mpp + MEK;
# reaction 8: Mpp + MKP3 -> Mpp_MKP3;
# reaction 9: Mpp_MKP3 -> MpT_MKP3_Y;
# reaction 10: MpT_MKP3_Y -> MpT + MKP3;
# reaction 11: MpT_MKP3_T -> M_MKP3_T;
# reaction 12: MpT + MKP3 -> MpT_MKP3_T;
# reaction 13: MpY_MKP3 -> M_MKP3_Y;
# reaction 14: M_MKP3_T -> M + MKP3;
# reaction 15: MpY + MKP3 -> MpY_MKP3;
# reaction 16: M_MKP3_Y -> M + MKP3;
#
# None
# <Model model_0000001 "Markevich2004_MAPK_phosphoRandomMM">
# reaction 0: M -> MpY;
# reaction 1: MpY -> Mpp;
# reaction 2: M -> MpT;
# reaction 3: MpT -> Mpp;
# reaction 4: Mpp -> MpT;
# reaction 5: MpT -> M;
# reaction 6: MpY -> M;
#
# None
# <Model model_0000001 "Markevich2004_MAPK_AllRandomElementary">
# reaction 0: M + MAPKK -> M_MAPKK_Y;
# reaction 1: M_MAPKK_Y -> MpY + MAPKK;
# reaction 2: MpY + MAPKK -> MpY_MAPKK;
# reaction 3: MpY_MAPKK -> Mpp + MAPKK;
# reaction 4: M + MAPKK -> M_MAPKK_T;
# reaction 5: M_MAPKK_T -> MpT + MAPKK;
# reaction 6: MpT + MAPKK -> MpT_MAPKK;
# reaction 7: MpT_MAPKK -> Mpp + MAPKK;
# reaction 8: Mpp + MKP -> Mpp_MKP_Y;
# reaction 9: Mpp_MKP_Y -> MpT_MKP_Y;
# reaction 10: MpT_MKP_Y -> MpT + MKP;
# reaction 11: MpT + MKP -> MpT_MKP_T;
# reaction 12: MpT_MKP_T -> M_MKP_T;
# reaction 13: M_MKP_T -> M + MKP;
# reaction 14: MpY + MKP -> MpY_MKP_Y;
# reaction 15: MpY_MKP_Y -> M_MKP_Y;
# reaction 16: M_MKP_Y -> M + MKP;
# reaction 17: Mpp + MKP -> Mpp_MKP_T;
# reaction 18: Mpp_MKP_T -> MpY_MKP_T;
# reaction 19: MpY_MKP_T -> MpY + MKP;
#
# None
# <Model Markevich2004_MAPK_orderedMM2kinases "Markevich2004_MAPK_orderedMM2kinases">
# reaction 0: M -> Mp;
# reaction 1: Mp -> Mpp;
# reaction 2: Mpp -> Mp;
# reaction 3: Mp -> M;
#
# None
# <Model Kofahl2004_PheromonePathway "Kofahl2004_PheromonePathway">
# reaction 0: alpha -> ;
# reaction 1: Ste2 -> Ste2a;
# reaction 2: Ste2a -> Ste2;
# reaction 3: Ste2a -> p;
# reaction 4: Ste2 -> ;
# reaction 5: Gabc -> GaGTP + Gbc;
# reaction 6: GaGTP -> GaGDP;
# reaction 7: GaGTP -> GaGDP;
# reaction 8: GaGDP + Gbc -> Gabc;
# reaction 9: Gbc + complexC -> complexD;
# reaction 10: complexD -> Gbc + complexC;
# reaction 11: Ste11 + Ste5 -> complexA;
# reaction 12: complexA -> Ste11 + Ste5;
# reaction 13: Fus3 + Ste7 -> complexB;
# reaction 14: complexB -> Fus3 + Ste7;
# reaction 15: complexA + complexB -> complexC;
# reaction 16: complexC -> Fus3 + Ste11 + Ste7 + Ste5;
# reaction 17: complexD + Ste20 -> complexE;
# reaction 18: complexE -> complexD + Ste20;
# reaction 19: complexE -> complexF;
# reaction 20: complexE -> Gbc + Ste7 + Ste5 + Fus3 + Ste20 + Ste11;
# reaction 21: complexF -> complexG;
# reaction 22: complexF -> Gbc + Ste7 + Ste5 + Fus3 + Ste20 + Ste11;
# reaction 23: complexG -> complexH;
# reaction 24: complexG -> Gbc + Ste7 + Ste5 + Fus3 + Ste20 + Ste11;
# reaction 25: complexH -> complexI;
# reaction 26: complexH -> Gbc + Ste7 + Ste5 + Fus3 + Ste20 + Ste11;
# reaction 27: complexI -> complexL + Fus3PP;
# reaction 28: complexL + Fus3 -> complexK;
# reaction 29: complexK -> complexL + Fus3;
# reaction 30: complexK -> complexI;
# reaction 31: complexL -> Gbc + Ste7 + Ste5 + Ste20 + Ste11;
# reaction 32: Fus3PP -> Fus3;
# reaction 33: Ste12 + Fus3PP -> Ste12a;
# reaction 34: Ste12a -> Ste12 + Fus3PP;
# reaction 35: Bar1 -> Bar1a;
# reaction 36: Bar1a -> Bar1;
# reaction 37: Bar1a -> Bar1aex;
# reaction 38: Far1 -> Far1PP;
# reaction 39: Far1PP -> Far1;
# reaction 40: Far1 -> Far1U;
# reaction 41: Gbc + Far1PP -> complexM;
# reaction 42: complexM -> Gbc + Far1PP;
# reaction 43: complexN -> Cdc28 + Far1PP;
# reaction 44: Cdc28 + Far1PP -> complexN;
# reaction 45: p -> Sst2;
# reaction 46: Sst2 -> p;
#
# None
# <Model Brown2004_NGF_EGF_signaling "Brown2004 - NGF and EGF signaling">
# reaction 0: EGF + freeEGFReceptor -> boundEGFReceptor;
# reaction 1: boundEGFReceptor -> EGF + freeEGFReceptor;
# reaction 2: NGF + freeNGFReceptor -> boundNGFReceptor;
# reaction 3: boundNGFReceptor -> NGF + freeNGFReceptor;
# reaction 4: SosInactive -> SosActive;
# reaction 5: SosInactive -> SosActive;
# reaction 6: SosActive -> SosInactive;
# reaction 7: RasInactive -> RasActive;
# reaction 8: RasActive -> RasInactive;
# reaction 9: Raf1Inactive -> Raf1Active;
# reaction 10: MekInactive -> MekActive;
# reaction 11: MekInactive -> MekActive;
# reaction 12: ErkInactive -> ErkActive;
# reaction 13: MekActive -> MekInactive;
# reaction 14: ErkActive -> ErkInactive;
# reaction 15: Raf1Active -> Raf1Inactive;
# reaction 16: P90RskInactive -> P90RskActive;
# reaction 17: PI3KInactive -> PI3KActive;
# reaction 18: PI3KInactive -> PI3KActive;
# reaction 19: AktInactive -> AktActive;
# reaction 20: Raf1Active -> Raf1Inactive;
# reaction 21: C3GInactive -> C3GActive;
# reaction 22: Rap1Inactive -> Rap1Active;
# reaction 23: Rap1Active -> Rap1Inactive;
# reaction 24: BRafInactive -> BRafActive;
# reaction 25: BRafActive -> BRafInactive;
#
# None
# <Model model_0000001 "Smolen2004_CircClock">
# reaction 0:  -> species_0000004;
# reaction 1:  -> species_0000007;
# reaction 2:  -> species_0000009;
# reaction 3:  -> species_0000008;
# reaction 4: species_0000008 -> ;
# reaction 5: species_0000009 -> ;
# reaction 6: species_0000007 -> ;
# reaction 7: species_0000004 -> species_0000005;
# reaction 8: species_0000005 -> species_0000006;
# reaction 9: species_0000006 -> species_0000001;
# reaction 10: species_0000001 -> species_0000002;
# reaction 11: species_0000002 -> species_0000003;
# reaction 12: species_0000003 -> ;
# reaction 13: species_0000008 -> ;
# reaction 14: species_0000009 -> ;
# reaction 15: species_0000007 -> ;
# reaction 16: species_0000004 -> ;
# reaction 17: species_0000005 -> ;
# reaction 18: species_0000006 -> ;
# reaction 19: species_0000001 -> ;
# reaction 20: species_0000002 -> ;
# reaction 21: species_0000003 -> ;
#
# None
# <Model vilarOscillator "Vilar2002_Oscillator">
# reaction 0: A + R -> C;
# reaction 1: A -> EmptySet;
# reaction 2: C -> R;
# reaction 3: R -> EmptySet;
# reaction 4: A + DA -> DAp;
# reaction 5: DAp -> A + DA;
# reaction 6: DA -> DA + MA;
# reaction 7: DAp -> DAp + MA;
# reaction 8: MA -> EmptySet;
# reaction 9: MA -> A + MA;
# reaction 10: A + DR -> DRp;
# reaction 11: DRp -> A + DR;
# reaction 12: DR -> DR + MR;
# reaction 13: DRp -> DRp + MR;
# reaction 14: MR -> EmptySet;
# reaction 15: MR -> MR + R;
#
# None
# <Model Tyson1999 "Tyson1999_CircClock">
# reaction 0: EmptySet -> M;
# reaction 1: EmptySet -> P;
# reaction 2: M -> EmptySet;
# reaction 3: P -> EmptySet;
# reaction 4: P -> EmptySet;
#
# None
# <Model BIOMD0000000037 "Marwan2003 - Genetics, regulatory hierarchy between genes">
# reaction 0: Pfr -> Pr;
# reaction 1: Pr -> Pfr;
# reaction 2: Xi -> Xa;
# reaction 3: Xa -> Xi;
# reaction 4: prepreS -> preS;
# reaction 5: preS -> S;
# reaction 6: Ya + Gluc -> Yi;
# reaction 7:  -> S;
# reaction 8:  -> V;
# reaction 9: S -> ;
# reaction 10: V -> ;
# reaction 11: Pr -> Pi;
#
# None
# <Model Rohwer2000_Phosphotransferase_System "Rohwer2000_Phosphotransferase_System">
# reaction 0: PEP + EI -> PyrPI;
# reaction 1: PyrPI -> EIP + Pyr;
# reaction 2: HPr + EIP -> EIPHPr;
# reaction 3: EIPHPr -> HPrP + EI;
# reaction 4: HPrP + EIIA -> HPrPIIA;
# reaction 5: HPrPIIA -> EIIAP + HPr;
# reaction 6: EIICB + EIIAP -> EIIAPIICB;
# reaction 7: EIIAPIICB -> EIICBP + EIIA;
# reaction 8: EIICBP + Glc -> EIICBPGlc;
# reaction 9: EIICBPGlc -> EIICB + GlcP;
#
# None
# <Model Marhl_Calcium_Oscillations_role_of_mitochondria_and_cytosolic_proteins "Marhl2000_CaOscillations">
# reaction 0: CaER -> Ca_cyt;
# reaction 1: CaER -> Ca_cyt;
# reaction 2: Ca_cyt -> CaER;
# reaction 3: CaM -> Ca_cyt;
# reaction 4: Ca_cyt -> CaM;
# reaction 5: CaPr -> Pr + Ca_cyt;
# reaction 6: Pr + Ca_cyt -> CaPr;
#
# None
# <Model Field1974_Oregonator "Field1974_Oregonator">
# reaction 0: Br + BrO3 -> HBrO2 + HOBr;
# reaction 1: Br + HBrO2 -> HOBr;
# reaction 2: BrO3 + HBrO2 -> Ce + HBrO2;
# reaction 3: HBrO2 -> BrO3 + HOBr;
# reaction 4: Ce -> Br;
#
# None
# <Model Kongas___Van_Beek "Kongas2007 - Creatine Kinase in energy metabolic signaling in muscle">
# reaction 0: ADPi + Pi -> ATPi;
# reaction 1: ATPi + Cri -> ADPi + PCri;
# reaction 2: ATP + Cr -> PCr + ADP;
# reaction 3: ATP -> ADP + P;
# reaction 4: Pi -> P;
# reaction 5: Cri -> Cr;
# reaction 6: ADPi -> ADP;
# reaction 7: PCri -> PCr;
# reaction 8: ATPi -> ATP;
#
# None
# <Model Glycolysis_Nielsen "Nielsen1998_Glycolysis">
# reaction 0:  -> ATP;
# reaction 1:  -> ADP;
# reaction 2:  -> NADH;
# reaction 3:  -> NAD;
# reaction 4:  -> GLC;
# reaction 5: F6P -> ;
# reaction 6: FBP -> ;
# reaction 7: GAP -> ;
# reaction 8: DPG -> ;
# reaction 9: PEP -> ;
# reaction 10: PYR -> ;
# reaction 11: ACA -> ;
# reaction 12: EtOH -> ;
# reaction 13: AMP -> ;
# reaction 14: P -> ;
# reaction 15: GLC + ATP -> F6P + ADP;
# reaction 16: F6P + ATP -> FBP + ADP;
# reaction 17: FBP -> GAP;
# reaction 18: GAP + NAD -> DPG + NADH;
# reaction 19: DPG + ADP -> PEP + ATP;
# reaction 20: PEP + ADP -> PYR + ATP;
# reaction 21: PYR -> ACA;
# reaction 22: ACA + NADH -> EtOH + NAD;
# reaction 23: AMP + ATP -> ADP;
# reaction 24: F6P -> P;
#
# None
# <Model Goldbeter_Calcium_Oscillation_based_on_CICR_AND_CA_channel_inhibition "Borghans1997 - Calcium Oscillation - Model 1">
# reaction 0: EC -> Z;
# reaction 1: Z -> Y;
# reaction 2: Y -> Z;
# reaction 3: Y -> Z;
# reaction 4: Z -> EC;
# reaction 5: Rho -> Fraction_Inactive_Channels;
# reaction 6: Fraction_Inactive_Channels -> Rho;
#
# None
# <Model Goldbeter_Calcium_Oscillation_based_on_CICR_AND_CA_Activated_degradation_of_IP3 "Borghans1997 - Calcium Oscillation - Model 2">
# reaction 0: EC -> Z;
# reaction 1: Z -> Y;
# reaction 2: Y -> Z;
# reaction 3: Y -> Z;
# reaction 4: Z -> EC;
# reaction 5:  -> A;
# reaction 6: A -> ;
# reaction 7: A -> ;
#
# None
# <Model Goldbeter_Calcium_Oscillation_based_onCICR_AND_two_pool_model "Borghans1997 - Calcium Oscillation - Model 3">
# reaction 0: EC -> Z;
# reaction 1: Z -> Y;
# reaction 2: Y -> Z;
# reaction 3: Y -> Z;
# reaction 4: Z -> EC;
# reaction 5: X -> Z;
# reaction 6: Z -> X;
# reaction 7: X -> Z;
#
# None
# <Model "Olsen2003_peroxidase">
# reaction 0: NADH + O2 -> H2O2 + NAD;
# reaction 1: per3 + H2O2 -> coI;
# reaction 2: ArH + coI -> Ar + coII;
# reaction 3: coII + ArH -> per3 + Ar;
# reaction 4: NADrad + O2 -> NAD + super;
# reaction 5: per3 + super -> coIII;
# reaction 6: super -> H2O2 + O2;
# reaction 7: NADrad + coIII -> NAD + coI;
# reaction 8: NADrad -> NAD2;
# reaction 9: per3 + NADrad -> per2 + NAD;
# reaction 10: per2 + O2 -> coIII;
# reaction 11: NADHres -> NADH;
# reaction 12: O2g -> O2;
# reaction 13: O2 -> O2g;
# reaction 14: NADH + Ar -> NADrad + ArH;
#
# None
# <Model Oxhamre_Bacteria_induced_Ca_oscillations "Oxhamre2005_Ca_oscillation">
# reaction 0: CaER -> Ca_Cyt;
# reaction 1: CaER -> Ca_Cyt;
# reaction 2: Ca_Cyt -> CaER;
#
# None
# <Model "Kholodenko1999 - EGFR signaling">
# reaction 0: R + EGF -> Ra;
# reaction 1: Ra -> R2;
# reaction 2: R2 -> RP;
# reaction 3: RP -> R2;
# reaction 4: RP + PLCg -> RPLCg;
# reaction 5: RPLCg -> RPLCgP;
# reaction 6: RPLCgP -> PLCgP + RP;
# reaction 7: PLCgP -> PLCg;
# reaction 8: Grb + RP -> RG;
# reaction 9: RG + SOS -> RGS;
# reaction 10: RGS -> GS + RP;
# reaction 11: GS -> Grb + SOS;
# reaction 12: Shc + RP -> RSh;
# reaction 13: RSh -> RShP;
# reaction 14: RShP -> RP + ShP;
# reaction 15: ShP -> Shc;
# reaction 16: RShP + Grb -> RShG;
# reaction 17: RShG -> ShG + RP;
# reaction 18: SOS + RShG -> RShGS;
# reaction 19: RShGS -> ShGS + RP;
# reaction 20: Grb + ShP -> ShG;
# reaction 21: ShG + SOS -> ShGS;
# reaction 22: ShGS -> GS + ShP;
# reaction 23: RShP + GS -> RShGS;
# reaction 24: PLCgP -> PLCgl;
#
# None
# <Model Sasagawa2005_MAPK "Sasagawa2005_MAPK">
# reaction 0: pro_EGFR -> EGFR;
# reaction 1: EGF + EGFR -> L_EGFR;
# reaction 2: L_EGFR -> L_EGFR_dimer;
# reaction 3: SOS + Grb2 -> SOS_Grb2;
# reaction 4: Grb2 + pSOS -> pSOS_Grb2;
# reaction 5: L_EGFR_dimer -> L_dpEGFR;
# reaction 6: L_dpEGFR + c_Cbl -> dpEGFR_c_Cbl;
# reaction 7: L_dpEGFR + pShc -> pShc_dpEGFR;
# reaction 8: pDok -> Dok;
# reaction 9: c_Cbl + pShc_dpEGFR -> pShc_dpEGFR_c_Cbl;
# reaction 10: pSOS -> SOS;
# reaction 11: pSOS_Grb2 -> SOS_Grb2;
# reaction 12: L_dpEGFR + Shc -> Shc_dpEGFR;
# reaction 13: Shc_dpEGFR -> pShc_dpEGFR;
# reaction 14: dpEGFR_c_Cbl -> dpEGFR_c_Cbl_ubiq;
# reaction 15: dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl;
# reaction 16: c_Cbl + Shc_dpEGFR -> Shc_dpEGFR_c_Cbl;
# reaction 17: Shc_dpEGFR_c_Cbl -> Shc_dpEGFR_c_Cbl_ubiq;
# reaction 18: Shc_dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl + Shc;
# reaction 19: pShc_dpEGFR_c_Cbl -> pShc_dpEGFR_c_Cbl_ubiq;
# reaction 20: pShc_dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl + pShc;
# reaction 21: Shc_dpEGFR_c_Cbl -> pShc_dpEGFR_c_Cbl;
# reaction 22: pShc + SOS_Grb2 -> Grb2_SOS_pShc;
# reaction 23: L_dpEGFR + Grb2_SOS_pShc -> Grb2_SOS_pShc_dpEGFR;
# reaction 24: pShc_dpEGFR + SOS_Grb2 -> Grb2_SOS_pShc_dpEGFR;
# reaction 25: c_Cbl + Grb2_SOS_pShc_dpEGFR -> Grb2_SOS_pShc_dpEGFR_c_Cbl;
# reaction 26: dpEGFR_c_Cbl + Grb2_SOS_pShc -> Grb2_SOS_pShc_dpEGFR_c_Cbl;
# reaction 27: Grb2_SOS_pShc_dpEGFR_c_Cbl -> Grb2_SOS_pShc_dpEGFR_c_Cbl_ubiq;
# reaction 28: Grb2_SOS_pShc_dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl + Grb2_SOS_pShc;
# reaction 29: Grb2_SOS_pShc -> Shc + SOS_Grb2;
# reaction 30: Dok -> pDok;
# reaction 31: pShc -> Shc;
# reaction 32: pFRS2 -> FRS2;
# reaction 33: Crk + C3G -> Crk_C3G;
# reaction 34: L_dpEGFR + FRS2 -> FRS2_dpEGFR;
# reaction 35: L_dpEGFR + pFRS2 -> pFRS2_dpEGFR;
# reaction 36: FRS2_dpEGFR -> pFRS2_dpEGFR;
# reaction 37: pFRS2_dpEGFR + Crk_C3G -> Crk_C3G_pFRS2_dpEGFR;
# reaction 38: FRS2_dpEGFR + c_Cbl -> FRS2_dpEGFR_c_Cbl;
# reaction 39: c_Cbl + pFRS2_dpEGFR -> pFRS2_dpEGFR_c_Cbl;
# reaction 40: pFRS2_dpEGFR_c_Cbl -> pFRS2_dpEGFR_c_Cbl_ubiq;
# reaction 41: FRS2_dpEGFR_c_Cbl -> FRS2_dpEGFR_c_Cbl_ubiq;
# reaction 42: FRS2_dpEGFR_c_Cbl -> pFRS2_dpEGFR_c_Cbl;
# reaction 43: pFRS2_dpEGFR_c_Cbl + Crk_C3G -> Crk_C3G_pFRS2_dpEGFR_c_Cbl;
# reaction 44: Crk_C3G_pFRS2_dpEGFR_c_Cbl -> Crk_C3G_pFRS2_dpEGFR_c_Cbl_ubiq;
# reaction 45: FRS2_dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl + FRS2;
# reaction 46: pFRS2_dpEGFR_c_Cbl_ubiq -> proteosome + c_Cbl + pFRS2;
# reaction 47: pDok + RasGAP -> pDok_RasGAP;
# reaction 48: SOS_Grb2 -> pSOS_Grb2;
# reaction 49: SOS -> pSOS;
# reaction 50: c_Raf + Ras_GTP -> c_Raf_Ras_GTP;
# reaction 51: Rap1_GTP + B_Raf -> B_Raf_Rap1_GTP;
# reaction 52: Ras_GTP + B_Raf -> B_Raf_Ras_GTP;
# reaction 53: ppMEK -> pMEK;
# reaction 54: pMEK -> MEK;
# reaction 55: ppMEK_ERK -> pMEK_ERK;
# reaction 56: pMEK_ERK -> MEK_ERK;
# reaction 57: ppERK -> dppERK;
# reaction 58: Ras_GTP -> Ras_GDP;
# reaction 59: Rap1_GTP -> Rap1_GDP;
# reaction 60: Rap1_GDP -> Rap1_GTP;
# reaction 61: Ras_GDP -> Ras_GTP;
# reaction 62: NGF + NGFR -> L_NGFR;
# reaction 63: L_NGFR -> pTrkA;
# reaction 64: pTrkA -> pTrkA_endo;
# reaction 65: pTrkA_endo -> degradation;
# reaction 66: pTrkA -> degradation;
# reaction 67: Shc + pTrkA -> Shc_pTrkA;
# reaction 68: pShc + pTrkA -> pShc_pTrkA;
# reaction 69: FRS2 + pTrkA -> FRS2_pTrkA;
# reaction 70: pFRS2 + pTrkA -> pFRS2_pTrkA;
# reaction 71: pTrkA_endo + Shc -> Shc_pTrkA_endo;
# reaction 72: pTrkA_endo + pShc -> pShc_pTrkA_endo;
# reaction 73: Shc_pTrkA_endo -> pShc_pTrkA_endo;
# reaction 74: Shc_pTrkA -> pShc_pTrkA;
# reaction 75: FRS2_pTrkA -> pFRS2_pTrkA;
# reaction 76: pTrkA_endo + FRS2 -> FRS2_pTrkA_endo;
# reaction 77: pTrkA_endo + pFRS2 -> pFRS2_pTrkA_endo;
# reaction 78: FRS2_pTrkA_endo -> pFRS2_pTrkA_endo;
# reaction 79: FRS2_pTrkA -> degradation + FRS2;
# reaction 80: pFRS2_pTrkA -> degradation + pFRS2;
# reaction 81: Shc_pTrkA -> degradation + Shc;
# reaction 82: pShc_pTrkA -> degradation + pShc;
# reaction 83: FRS2_pTrkA_endo -> degradation + FRS2;
# reaction 84: Shc_pTrkA_endo -> degradation + Shc;
# reaction 85: pShc_pTrkA_endo -> degradation + pShc;
# reaction 86: SOS_Grb2 + pShc_pTrkA_endo -> Grb2_SOS_pShc_pTrkA_endo;
# reaction 87: SOS_Grb2 + pShc_pTrkA -> Grb2_SOS_pShc_pTrkA;
# reaction 88: Grb2_SOS_pShc_pTrkA -> Grb2_SOS_pShc_pTrkA_endo;
# reaction 89: Crk_C3G_pFRS2_pTrkA -> Crk_C3G_pFRS2_pTrkA_endo;
# reaction 90: pFRS2_pTrkA -> pFRS2_pTrkA_endo;
# reaction 91: FRS2_pTrkA -> FRS2_pTrkA_endo;
# reaction 92: pShc_pTrkA -> pShc_pTrkA_endo;
# reaction 93: Shc_pTrkA -> Shc_pTrkA_endo;
# reaction 94: Crk_C3G + pFRS2_pTrkA -> Crk_C3G_pFRS2_pTrkA;
# reaction 95: Crk_C3G + pFRS2_pTrkA_endo -> Crk_C3G_pFRS2_pTrkA_endo;
# reaction 96: Grb2_SOS_pShc + pTrkA -> Grb2_SOS_pShc_pTrkA;
# reaction 97: Grb2_SOS_pShc + pTrkA_endo -> Grb2_SOS_pShc_pTrkA_endo;
# reaction 98: Crk_C3G_pFRS2_pTrkA -> degradation + pFRS2 + Crk_C3G;
# reaction 99: Crk_C3G_pFRS2_pTrkA_endo -> degradation + Crk_C3G + pFRS2;
# reaction 100: Grb2_SOS_pShc_pTrkA -> degradation + Grb2_SOS_pShc;
# reaction 101: Grb2_SOS_pShc_pTrkA_endo -> degradation + Grb2_SOS_pShc;
# reaction 102: pFRS2_pTrkA_endo -> degradation + pFRS2;
# reaction 103: pro_TrkA -> NGFR;
# reaction 104: Shc + dpEGFR_c_Cbl -> Shc_dpEGFR_c_Cbl;
# reaction 105: dpEGFR_c_Cbl + pShc -> pShc_dpEGFR_c_Cbl;
# reaction 106: pShc_dpEGFR_c_Cbl + SOS_Grb2 -> Grb2_SOS_pShc_dpEGFR_c_Cbl;
# reaction 107: c_Cbl + Crk_C3G_pFRS2_dpEGFR -> Crk_C3G_pFRS2_dpEGFR_c_Cbl;
# reaction 108: dpEGFR_c_Cbl + FRS2 -> FRS2_dpEGFR_c_Cbl;
# reaction 109: dpEGFR_c_Cbl + pFRS2 -> pFRS2_dpEGFR_c_Cbl;
# reaction 110: Ras_GTP -> Ras_GDP;
# reaction 111: Rap1_GTP -> Rap1_GDP;
# reaction 112: Dok -> pDok;
# reaction 113: Grb2_SOS_pShc -> pShc + pSOS_Grb2;
# reaction 114: ERK + MEK -> MEK_ERK;
# reaction 115: ERK + pMEK -> pMEK_ERK;
# reaction 116: ERK + ppMEK -> ppMEK_ERK;
# reaction 117: ppMEK_ERK -> ppERK + ppMEK;
# reaction 118: c_Raf_Ras_GTP -> c_Raf + Ras_GDP;
# reaction 119: B_Raf_Ras_GTP -> B_Raf + Ras_GDP;
# reaction 120: B_Raf_Rap1_GTP -> B_Raf + Rap1_GDP;
# reaction 121: c_Raf_Ras_GTP + MEK -> c_Raf_Ras_GTP_MEK;
# reaction 122: c_Raf_Ras_GTP + pMEK -> c_Raf_Ras_GTP_pMEK;
# reaction 123: c_Raf_Ras_GTP + MEK_ERK -> c_Raf_Ras_GTP_MEK_ERK;
# reaction 124: c_Raf_Ras_GTP + pMEK_ERK -> c_Raf_Ras_GTP_pMEK_ERK;
# reaction 125: B_Raf_Ras_GTP + MEK -> B_Raf_Ras_GTP_MEK;
# reaction 126: B_Raf_Ras_GTP + pMEK -> B_Raf_Ras_GTP_pMEK;
# reaction 127: B_Raf_Ras_GTP + MEK_ERK -> B_Raf_Ras_GTP_MEK_ERK;
# reaction 128: B_Raf_Ras_GTP + pMEK_ERK -> B_Raf_Ras_GTP_pMEK_ERK;
# reaction 129: B_Raf_Rap1_GTP + MEK -> B_Raf_Rap1_GTP_MEK;
# reaction 130: B_Raf_Rap1_GTP + pMEK -> B_Raf_Rap1_GTP_pMEK;
# reaction 131: B_Raf_Rap1_GTP + MEK_ERK -> B_Raf_Rap1_GTP_MEK_ERK;
# reaction 132: B_Raf_Rap1_GTP + pMEK_ERK -> B_Raf_Rap1_GTP_pMEK_ERK;
# reaction 133: c_Raf_Ras_GTP_MEK -> c_Raf_Ras_GTP + pMEK;
# reaction 134: c_Raf_Ras_GTP_pMEK -> c_Raf_Ras_GTP + ppMEK;
# reaction 135: c_Raf_Ras_GTP_MEK_ERK -> c_Raf_Ras_GTP + pMEK_ERK;
# reaction 136: c_Raf_Ras_GTP_pMEK_ERK -> c_Raf_Ras_GTP + ppMEK_ERK;
# reaction 137: B_Raf_Ras_GTP_MEK -> B_Raf_Ras_GTP + pMEK;
# reaction 138: B_Raf_Ras_GTP_pMEK -> B_Raf_Ras_GTP + ppMEK;
# reaction 139: B_Raf_Ras_GTP_MEK_ERK -> B_Raf_Ras_GTP + pMEK_ERK;
# reaction 140: B_Raf_Ras_GTP_pMEK_ERK -> B_Raf_Ras_GTP + ppMEK_ERK;
# reaction 141: B_Raf_Rap1_GTP_MEK -> B_Raf_Rap1_GTP + pMEK;
# reaction 142: B_Raf_Rap1_GTP_pMEK -> B_Raf_Rap1_GTP + ppMEK;
# reaction 143: B_Raf_Rap1_GTP_MEK_ERK -> B_Raf_Rap1_GTP + pMEK_ERK;
# reaction 144: B_Raf_Rap1_GTP_pMEK_ERK -> B_Raf_Rap1_GTP + ppMEK_ERK;
# reaction 145: Crk_C3G_pFRS2_dpEGFR_c_Cbl_ubiq -> c_Cbl + pFRS2 + Crk_C3G;
# reaction 146: MKP3 + dppERK -> dppERK_MKP3;
# reaction 147: MKP3 + ppERK -> ppERK_MKP3;
# reaction 148: ppERK_MKP3 -> ERK + MKP3;
# reaction 149: dppERK_MKP3 -> ppERK + ERK + MKP3;
#
# None
# <Model Kinetic_modelling_of_Amadori_degradation "Martins2003_AmadoriDegradation">
# reaction 0: DFG -> E1;
# reaction 1: DFG -> E2;
# reaction 2: DFG -> Gly + Cn;
# reaction 3: E1 -> Gly + _3DG;
# reaction 4: _3DG -> Cn;
# reaction 5: _3DG -> FA;
# reaction 6: E2 -> Gly + _1DG;
# reaction 7: _1DG -> Cn;
# reaction 8: _1DG -> AA;
# reaction 9: E1 -> Gly + Man;
# reaction 10: E1 -> Gly + Glu;
# reaction 11: Man -> Glu;
# reaction 12: Glu -> _3DG;
# reaction 13: Gly + Cn -> Mel;
# reaction 14: Cn -> AA + FA + MG;
# reaction 15: E2 -> Gly + Fru;
#
# None

# %%
 if (kl.isSetMath()):
          formula = formulaToString(kl.getMath());
          print("Reaction " + str(n) + ", formula: " + formula + "\n");

# %%
# Iterate over reactions
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
model = document.getModel()
for n in range(model.getNumReactions()):
    reaction = model.getReaction(n)
    stg = " "
    for m in range(reaction.getNumReactants()):
        reactant = reaction.getReactant(m)
        stg += " " + reactant.getSpecies()
    stg += " -> "
    for m in range(reaction.getNumProducts()):
        reactant = reaction.getProduct(m)
        stg += " " +reactant.getSpecies()
    kinetics = reaction.getKineticLaw()
    stg += "; "
    if kinetics.isSetMath():
       math = kinetics.getMath()
       if math.getNumChildren() > 0:
         stg += " " + math.getLeftChild().getId()
         new_math = math.getRightChild()
         if new_math is not None:
            if new_math.getLeftChild() is not None:
              stg += " " + new_math.getLeftChild()
            if new_math.getRightChild() is not None:
              stg += " " + new_math.getRigthChild()
    print stg

# %%
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
m = document.getModel()

for i in range(0, m.getNumReactions()):
  re = m.getReaction(i);
  import pdb; pdb.set_trace()
  m.printAnnotation(re);

# %%
dir(re)

# %%
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
m = document.getModel()

for i in range(0, m.getNumReactions()):
  re = m.getReaction(i);
  import pdb; pdb.set_trace()
  m.printAnnotation(re);

    # SpeciesReference (Reacatant)
  for j in range(0, re.getNumReactants()):
    rt = re.getReactant(j);
    if (rt.isSetAnnotation()):
      print("     ");
    libsbml.printAnnotation(rt, rt.getSpecies());

  # SpeciesReference (Product) 
  for j in range(0, re.getNumProducts()):
    rt = re.getProduct(j);
    if (rt.isSetAnnotation()):
      print("     ");
    printAnnotation(rt, rt.getSpecies());

  # ModifierSpeciesReference (Modifiers)
  for j in range(0, re.getNumModifiers()):
      md = re.getModifier(j);
      if (md.isSetAnnotation()):
        print("     ");
      printAnnotation(md, md.getSpecies());

  # KineticLaw 
  if (re.isSetKineticLaw()):
    kl = re.getKineticLaw();
    if (kl.isSetAnnotation()):
      print("   ");
    printAnnotation(kl);

    # Parameter   
    for j in range(0, kl.getNumParameters()):
      pa = kl.getParameter(j);
      if (pa.isSetAnnotation()):
        print("      ");
      printAnnotation(pa);
  
# Species 
for i in range(0, m.getNumSpecies()):
  sp = m.getSpecies(i);
  printAnnotation(sp);
  
# Compartments 
for i in range(0, m.getNumCompartments()):
  sp = m.getCompartment(i);
  printAnnotation(sp);

# %% [markdown]
# # Doing math

# %%
expected = "1 + f(x)"
 
xml = "<?xml version='1.0' encoding='UTF-8'?>"\
       "<math xmlns='http://www.w3.org/1998/Math/MathML'>"\
       "  <apply> <plus/> <cn> 1 </cn>"\
       "                  <apply> <ci> f </ci> <ci> x </ci> </apply>"\
       "  </apply>"\
       "</math>"
 
ast    = libsbml.readMathMLFromString(xml)
result = libsbml.formulaToString(ast)
 
if (result == expected):
     print "Got expected result"
else:
     print "Mismatch after readMathMLFromString()"
 
new_mathml = libsbml.parseFormula(result)
new_string = libsbml.writeMathMLToString(new_mathml)
 
print "Result of writing AST to string: "
print new_string

# %%
x = 3
def f(x):
    return x + 1
eval(expected)

# %%
ast
