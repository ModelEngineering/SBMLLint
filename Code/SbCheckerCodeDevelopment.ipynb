# %%
import sys
import libsbml as libsbml

# %% [markdown]
# # Reading a document

# %%
def check(value, message):
   """If 'value' is None, prints an error message constructed using
   'message' and then exits with status code 1.  If 'value' is an integer,
   it assumes it is a libSBML return status code.  If the code value is
   LIBSBML_OPERATION_SUCCESS, returns without further action; if it is not,
   prints an error message constructed using 'message' along with text from
   libSBML explaining the meaning of the code, and exits with status code 1.
   """
   if value == None:
     raise SystemExit('LibSBML returned a null value trying to ' + message + '.')
   elif type(value) is int:
     if value == LIBSBML_OPERATION_SUCCESS:
       return
     else:
       err_msg = 'Error encountered trying to ' + message + '.' \
                 + 'LibSBML returned error code ' + str(value) + ': "' \
                 + OperationReturnValue_toString(value).strip() + '"'
       raise SystemExit(err_msg)
   else:
     return

# %%
# Iterate over species
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
model = document.getModel()
for n in range(model.getNumSpecies()):
    print model.getSpecies(n).getId()
# Out:
#   File "<ipython-input-25-64ef866207c5>", line 6
#     #print model.getSpecies(n).getId()
#                                       ^
# IndentationError: expected an indented block

# %%
 if (kl.isSetMath()):
          formula = formulaToString(kl.getMath());
          print("Reaction " + str(n) + ", formula: " + formula + "\n");

# %%
# Iterate over reactions
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
model = document.getModel()
for n in range(model.getNumReactions()):
    reaction = model.getReaction(n)
    stg = " "
    for m in range(reaction.getNumReactants()):
        reactant = reaction.getReactant(m)
        stg += " " + reactant.getSpecies()
    stg += " -> "
    for m in range(reaction.getNumProducts()):
        reactant = reaction.getProduct(m)
        stg += " " +reactant.getSpecies()
    kinetics = reaction.getKineticLaw()
    stg += "; "
    if kinetics.isSetMath():
       math = kinetics.getMath()
       if math.getNumChildren() > 0:
         stg += " " + math.getLeftChild().getId()
         new_math = math.getRightChild()
         if new_math is not None:
            if new_math.getLeftChild() is not None:
              stg += " " + new_math.getLeftChild()
            if new_math.getRightChild() is not None:
              stg += " " + new_math.getRigthChild()
    print stg
# Out:
#   x0 ->  L;
#   T2PR ->  T3P R;
#   T2R ->  T3 R;
#   T3PR ->  T4P R;
#   T3R ->  T4 R;
#   LT2PR ->  LT3P R;
#   LT2R ->  LT3 R;
#   LT3PR ->  LT4P R;
#   LT3R ->  LT4 R;
#   T3PR Bp ->  T2PR Bp;
#   T3R Bp ->  T2R Bp;
#   T3P Bp ->  T2P Bp;
#   T3 Bp ->  T2 Bp;
#   T4PR Bp ->  T3PR Bp;
#   T4R Bp ->  T3R Bp;
#   T4P Bp ->  T3P Bp;
#   T4 Bp ->  T3 Bp;
#   LT3PR Bp ->  LT2PR Bp;
#   LT3R Bp ->  LT2R Bp;
#   LT3P Bp ->  LT2P Bp;
#   LT3 Bp ->  LT2 Bp;
#   LT4PR Bp ->  LT3PR Bp;
#   LT4R Bp ->  LT3R Bp;
#   LT4P Bp ->  LT3P Bp;
#   LT4 Bp ->  LT3 Bp;
#   LT2PR ->  LT2P R;
#   LT2R ->  LT2 R;
#   LT3PR ->  LT3P R;
#   LT3R ->  LT3 R;
#   LT4PR ->  LT4P R;
#   LT4R ->  LT4 R;
#   T2PR ->  T2P R;
#   T2R ->  T2 R;
#   T3PR ->  T3P R;
#   T3R ->  T3 R;
#   T4PR ->  T4P R;
#   T4R ->  T4 R;
#   LT2P R ->  LT2PR;
#   LT2 R ->  LT2R;
#   LT3P R ->  LT3PR;
#   LT3 R ->  LT3R;
#   LT4P R ->  LT4PR;
#   LT4 R ->  LT4R;
#   T2P R ->  T2PR;
#   T2 R ->  T2R;
#   T3P R ->  T3PR;
#   T3 R ->  T3R;
#   T4P R ->  T4PR;
#   T4 R ->  T4R;
#   L T2PR ->  LT2PR;
#   L T2R ->  LT2R;
#   L T2P ->  LT2P;
#   L T2 ->  LT2;
#   L T3PR ->  LT3PR;
#   L T3R ->  LT3R;
#   L T3P ->  LT3P;
#   L T3 ->  LT3;
#   L T4PR ->  LT4PR;
#   L T4R ->  LT4R;
#   L T4P ->  LT4P;
#   L T4 ->  LT4;
#   LT2PR ->  L T2PR;
#   LT2R ->  L T2R;
#   LT2P ->  L T2P;
#   LT2 ->  L T2;
#   LT3PR ->  L T3PR;
#   LT3R ->  L T3R;
#   LT3P ->  L T3P;
#   LT3 ->  L T3;
#   LT4PR ->  L T4PR;
#   LT4R ->  L T4R;
#   LT4P ->  L T4P;
#   LT4 ->  L T4;
#   T2R ->  T2pR;
#   T2 ->  T2p;
#   T3R ->  T3pR;
#   T3 ->  T3p;
#   T4R ->  T4pR;
#   T4 ->  T4p;
#   LT2R ->  LT2pR;
#   LT2 ->  LT2p;
#   LT3R ->  LT3pR;
#   LT3 ->  LT3p;
#   LT4R ->  LT4pR;
#   LT4 ->  LT4p;
#   Bp ->  B;
#   Yp Z ->  Y Z;
#   LT2pR B ->  LT2R Bp;
#   LT2p B ->  LT2 Bp;
#   LT3pR B ->  LT3R Bp;
#   LT3p B ->  LT3 Bp;
#   LT4pR B ->  LT4R Bp;
#   LT4p B ->  LT4 Bp;
#   T2pR B ->  T2R Bp;
#   T2p B ->  T2 Bp;
#   T3pR B ->  T3R Bp;
#   T3p B ->  T3 Bp;
#   T4pR B ->  T4R Bp;
#   T4p B ->  T4 Bp;
#   LT2pR Y ->  LT2R Yp;
#   LT2p Y ->  LT2 Yp;
#   LT3pR Y ->  LT3R Yp;
#   LT3p Y ->  LT3 Yp;
#   LT4pR Y ->  LT4R Yp;
#   LT4p Y ->  LT4 Yp;
#   T2pR Y ->  T2R Yp;
#   T2p Y ->  T2 Yp;
#   T3pR Y ->  T3R Yp;
#   T3p Y ->  T3 Yp;
#   T4pR Y ->  T4R Yp;
#   T4p Y ->  T4 Yp;

# %%
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
m = document.getModel()

for i in range(0, m.getNumReactions()):
  re = m.getReaction(i);
  import pdb; pdb.set_trace()
  m.printAnnotation(re);

# %%
dir(re)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__swig_getmethods__',
#  '__swig_setmethods__',
#  '__weakref__',
#  '_s',
#  'addCVTerm',
#  'addModifier',
#  'addProduct',
#  'addReactant',
#  'all_elements',
#  'all_elements_from_plugins',
#  'annotation',
#  'annotation_string',
#  'appendAnnotation',
#  'appendNotes',
#  'checkCompatibility',
#  'checkMathMLNamespace',
#  'clone',
#  'column',
#  'compartment',
#  'connectToChild',
#  'connectToParent',
#  'containsUndeclaredUnits',
#  'createKineticLaw',
#  'createModifier',
#  'createProduct',
#  'createReactant',
#  'cv_terms',
#  'deleteDisabledPlugins',
#  'derived_unit_definition',
#  'disablePackage',
#  'divideAssignmentsToSIdByFunction',
#  'element_name',
#  'enablePackage',
#  'enablePackageInternal',
#  'fast',
#  'getAncestorOfType',
#  'getAnnotation',
#  'getAnnotationString',
#  'getCVTerm',
#  'getCVTerms',
#  'getColumn',
#  'getCompartment',
#  'getDerivedUnitDefinition',
#  'getDisabledPlugin',
#  'getElementByMetaId',
#  'getElementBySId',
#  'getElementFromPluginsByMetaId',
#  'getElementFromPluginsBySId',
#  'getElementName',
#  'getFast',
#  'getId',
#  'getKineticLaw',
#  'getLevel',
#  'getLine',
#  'getListOfAllElements',
#  'getListOfAllElementsFromPlugins',
#  'getListOfModifiers',
#  'getListOfProducts',
#  'getListOfReactants',
#  'getMetaId',
#  'getModel',
#  'getModelHistory',
#  'getModifier',
#  'getName',
#  'getNamespaces',
#  'getNotes',
#  'getNotesString',
#  'getNumCVTerms',
#  'getNumDisabledPlugins',
#  'getNumModifiers',
#  'getNumPlugins',
#  'getNumProducts',
#  'getNumReactants',
#  'getPackageName',
#  'getPackageVersion',
#  'getParentSBMLObject',
#  'getPlugin',
#  'getPrefix',
#  'getProduct',
#  'getReactant',
#  'getResourceBiologicalQualifier',
#  'getResourceModelQualifier',
#  'getReversible',
#  'getSBMLDocument',
#  'getSBMLNamespaces',
#  'getSBOTerm',
#  'getSBOTermAsURL',
#  'getSBOTermID',
#  'getTypeCode',
#  'getURI',
#  'getVersion',
#  'hasNonstandardIdentifierBeginningWith',
#  'hasRequiredAttributes',
#  'hasRequiredElements',
#  'hasValidLevelVersionNamespaceCombination',
#  'id',
#  'initDefaults',
#  'isPackageEnabled',
#  'isPackageURIEnabled',
#  'isPkgEnabled',
#  'isPkgURIEnabled',
#  'isSetAnnotation',
#  'isSetCompartment',
#  'isSetFast',
#  'isSetId',
#  'isSetKineticLaw',
#  'isSetMetaId',
#  'isSetModelHistory',
#  'isSetName',
#  'isSetNotes',
#  'isSetReversible',
#  'isSetSBOTerm',
#  'isSetUserData',
#  'level',
#  'line',
#  'matchesRequiredSBMLNamespacesForAddition',
#  'matchesSBMLNamespaces',
#  'meta_id',
#  'model',
#  'modifiers',
#  'multiplyAssignmentsToSIdByFunction',
#  'name',
#  'namespaces',
#  'notes',
#  'notes_string',
#  'num_cv_terms',
#  'num_disabled_plugins',
#  'num_modifiers',
#  'num_plugins',
#  'num_products',
#  'num_reactants',
#  'package_name',
#  'package_version',
#  'prefix',
#  'prependStringToAllIdentifiers',
#  'products',
#  'reactants',
#  'removeFromParentAndDelete',
#  'removeModifier',
#  'removeProduct',
#  'removeReactant',
#  'removeTopLevelAnnotationElement',
#  'renameMetaIdRefs',
#  'renameSIdRefs',
#  'renameUnitSIdRefs',
#  'replaceSIDWithFunction',
#  'replaceTopLevelAnnotationElement',
#  'reversible',
#  'sbml_namespaces',
#  'sbml_namespaces_and_own',
#  'sbo_term',
#  'sbo_term_as_url',
#  'sbo_term_id',
#  'setAnnotation',
#  'setCompartment',
#  'setFast',
#  'setId',
#  'setKineticLaw',
#  'setMetaId',
#  'setModelHistory',
#  'setName',
#  'setNamespaces',
#  'setNotes',
#  'setReversible',
#  'setSBMLNamespacesAndOwn',
#  'setSBOTerm',
#  'this',
#  'toSBML',
#  'toXMLNode',
#  'transformIdentifiers',
#  'type_code',
#  'unsetAnnotation',
#  'unsetCVTerms',
#  'unsetCompartment',
#  'unsetFast',
#  'unsetId',
#  'unsetKineticLaw',
#  'unsetMetaId',
#  'unsetModelHistory',
#  'unsetName',
#  'unsetNotes',
#  'unsetReversible',
#  'unsetSBOTerm',
#  'unsetUserData',
#  'uri',
#  'version',
#  'writeExtensionElements']

# %%
reader = libsbml.SBMLReader()
document = reader.readSBML("chemotaxis.xml")
m = document.getModel()

for i in range(0, m.getNumReactions()):
  re = m.getReaction(i);
  import pdb; pdb.set_trace()
  m.printAnnotation(re);

    # SpeciesReference (Reacatant)
  for j in range(0, re.getNumReactants()):
    rt = re.getReactant(j);
    if (rt.isSetAnnotation()):
      print("     ");
    libsbml.printAnnotation(rt, rt.getSpecies());

  # SpeciesReference (Product) 
  for j in range(0, re.getNumProducts()):
    rt = re.getProduct(j);
    if (rt.isSetAnnotation()):
      print("     ");
    printAnnotation(rt, rt.getSpecies());

  # ModifierSpeciesReference (Modifiers)
  for j in range(0, re.getNumModifiers()):
      md = re.getModifier(j);
      if (md.isSetAnnotation()):
        print("     ");
      printAnnotation(md, md.getSpecies());

  # KineticLaw 
  if (re.isSetKineticLaw()):
    kl = re.getKineticLaw();
    if (kl.isSetAnnotation()):
      print("   ");
    printAnnotation(kl);

    # Parameter   
    for j in range(0, kl.getNumParameters()):
      pa = kl.getParameter(j);
      if (pa.isSetAnnotation()):
        print("      ");
      printAnnotation(pa);
  
# Species 
for i in range(0, m.getNumSpecies()):
  sp = m.getSpecies(i);
  printAnnotation(sp);
  
# Compartments 
for i in range(0, m.getNumCompartments()):
  sp = m.getCompartment(i);
  printAnnotation(sp);
# Out:
# > <ipython-input-20-3594cc21d3ff>(8)<module>()
# -> m.printAnnotation(re);
# (Pdb) dir(re)
# ['__class__', '__del__', '__delattr__', '__dict__', '__doc__', '__eq__', '__format__', '__getattr__', '__getattribute__', '__hash__', '__init__', '__metaclass__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__swig_destroy__', '__swig_getmethods__', '__swig_setmethods__', '__weakref__', '_s', 'addCVTerm', 'addModifier', 'addProduct', 'addReactant', 'all_elements', 'all_elements_from_plugins', 'annotation', 'annotation_string', 'appendAnnotation', 'appendNotes', 'checkCompatibility', 'checkMathMLNamespace', 'clone', 'column', 'compartment', 'connectToChild', 'connectToParent', 'containsUndeclaredUnits', 'createKineticLaw', 'createModifier', 'createProduct', 'createReactant', 'cv_terms', 'deleteDisabledPlugins', 'derived_unit_definition', 'disablePackage', 'divideAssignmentsToSIdByFunction', 'element_name', 'enablePackage', 'enablePackageInternal', 'fast', 'getAncestorOfType', 'getAnnotation', 'getAnnotationString', 'getCVTerm', 'getCVTerms', 'getColumn', 'getCompartment', 'getDerivedUnitDefinition', 'getDisabledPlugin', 'getElementByMetaId', 'getElementBySId', 'getElementFromPluginsByMetaId', 'getElementFromPluginsBySId', 'getElementName', 'getFast', 'getId', 'getKineticLaw', 'getLevel', 'getLine', 'getListOfAllElements', 'getListOfAllElementsFromPlugins', 'getListOfModifiers', 'getListOfProducts', 'getListOfReactants', 'getMetaId', 'getModel', 'getModelHistory', 'getModifier', 'getName', 'getNamespaces', 'getNotes', 'getNotesString', 'getNumCVTerms', 'getNumDisabledPlugins', 'getNumModifiers', 'getNumPlugins', 'getNumProducts', 'getNumReactants', 'getPackageName', 'getPackageVersion', 'getParentSBMLObject', 'getPlugin', 'getPrefix', 'getProduct', 'getReactant', 'getResourceBiologicalQualifier', 'getResourceModelQualifier', 'getReversible', 'getSBMLDocument', 'getSBMLNamespaces', 'getSBOTerm', 'getSBOTermAsURL', 'getSBOTermID', 'getTypeCode', 'getURI', 'getVersion', 'hasNonstandardIdentifierBeginningWith', 'hasRequiredAttributes', 'hasRequiredElements', 'hasValidLevelVersionNamespaceCombination', 'id', 'initDefaults', 'isPackageEnabled', 'isPackageURIEnabled', 'isPkgEnabled', 'isPkgURIEnabled', 'isSetAnnotation', 'isSetCompartment', 'isSetFast', 'isSetId', 'isSetKineticLaw', 'isSetMetaId', 'isSetModelHistory', 'isSetName', 'isSetNotes', 'isSetReversible', 'isSetSBOTerm', 'isSetUserData', 'level', 'line', 'matchesRequiredSBMLNamespacesForAddition', 'matchesSBMLNamespaces', 'meta_id', 'model', 'modifiers', 'multiplyAssignmentsToSIdByFunction', 'name', 'namespaces', 'notes', 'notes_string', 'num_cv_terms', 'num_disabled_plugins', 'num_modifiers', 'num_plugins', 'num_products', 'num_reactants', 'package_name', 'package_version', 'prefix', 'prependStringToAllIdentifiers', 'products', 'reactants', 'removeFromParentAndDelete', 'removeModifier', 'removeProduct', 'removeReactant', 'removeTopLevelAnnotationElement', 'renameMetaIdRefs', 'renameSIdRefs', 'renameUnitSIdRefs', 'replaceSIDWithFunction', 'replaceTopLevelAnnotationElement', 'reversible', 'sbml_namespaces', 'sbml_namespaces_and_own', 'sbo_term', 'sbo_term_as_url', 'sbo_term_id', 'setAnnotation', 'setCompartment', 'setFast', 'setId', 'setKineticLaw', 'setMetaId', 'setModelHistory', 'setName', 'setNamespaces', 'setNotes', 'setReversible', 'setSBMLNamespacesAndOwn', 'setSBOTerm', 'this', 'toSBML', 'toXMLNode', 'transformIdentifiers', 'type_code', 'unsetAnnotation', 'unsetCVTerms', 'unsetCompartment', 'unsetFast', 'unsetId', 'unsetKineticLaw', 'unsetMetaId', 'unsetModelHistory', 'unsetName', 'unsetNotes', 'unsetReversible', 'unsetSBOTerm', 'unsetUserData', 'uri', 'version', 'writeExtensionElements']
# (Pdb) re?
# *** SyntaxError: invalid syntax (<stdin>, line 1)
# (Pdb) help(re)
# *** No help on (re)
# (Pdb) re.getName()
# ''
# (Pdb) re.getListOfProducts()
# <ListOfSpeciesReferences[1]>
# (Pdb) [str(p) for re.getListOfProducts()]
# *** SyntaxError: invalid syntax (<stdin>, line 1)
# (Pdb) [str(p) for p in re.getListOfProducts()]
# ['<SpeciesReference>']
# -------------------------------------------------------------------------
# KeyboardInterrupt                       Traceback (most recent call last)
# <ipython-input-20-3594cc21d3ff> in <module>()
#       6   re = m.getReaction(i);
#       7   import pdb; pdb.set_trace()
# ----> 8   m.printAnnotation(re);
#       9
#      10     # SpeciesReference (Reacatant)
#
# <ipython-input-20-3594cc21d3ff> in <module>()
#       6   re = m.getReaction(i);
#       7   import pdb; pdb.set_trace()
# ----> 8   m.printAnnotation(re);
#       9
#      10     # SpeciesReference (Reacatant)
#
# /home/ubuntu/miniconda2/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      47             return # None
#      48         if event == 'line':
# ---> 49             return self.dispatch_line(frame)
#      50         if event == 'call':
#      51             return self.dispatch_call(frame, arg)
#
# /home/ubuntu/miniconda2/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      65     def dispatch_line(self, frame):
#      66         if self.stop_here(frame) or self.break_here(frame):
# ---> 67             self.user_line(frame)
#      68             if self.quitting: raise BdbQuit
#      69         return self.trace_dispatch
#
# /home/ubuntu/miniconda2/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /home/ubuntu/miniconda2/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /home/ubuntu/miniconda2/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     687             self._parent_ident,
#     688             self._parent_header,
# --> 689             password=False,
#     690         )
#     691
#
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     717             except KeyboardInterrupt:
#     718                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 719                 raise KeyboardInterrupt
#     720             else:
#     721                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Doing math

# %%
expected = "1 + f(x)"
 
xml = "<?xml version='1.0' encoding='UTF-8'?>"\
       "<math xmlns='http://www.w3.org/1998/Math/MathML'>"\
       "  <apply> <plus/> <cn> 1 </cn>"\
       "                  <apply> <ci> f </ci> <ci> x </ci> </apply>"\
       "  </apply>"\
       "</math>"
 
ast    = libsbml.readMathMLFromString(xml)
result = libsbml.formulaToString(ast)
 
if (result == expected):
     print "Got expected result"
else:
     print "Mismatch after readMathMLFromString()"
 
new_mathml = libsbml.parseFormula(result)
new_string = libsbml.writeMathMLToString(new_mathml)
 
print "Result of writing AST to string: "
print new_string
# Out:
# Got expected result
# Result of writing AST to string:
# <?xml version="1.0" encoding="UTF-8"?>
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <apply>
#     <plus/>
#     <cn type="integer"> 1 </cn>
#     <apply>
#       <ci> f </ci>
#       <ci> x </ci>
#     </apply>
#   </apply>
# </math>

# %%
x = 3
def f(x):
    return x + 1
eval(expected)
# Out:
# 5

# %%
ast
# Out:
# <libsbml.ASTNode; proxy of <Swig Object of type 'ASTNode_t *' at 0x7f78ff013e70> >
